# %% [markdown]
# # Tohoku tsunami inversion
# ## 4. Inversion using discrete adjoint
#
# Let's perform a first source inversion using a single basis function using the discrete adjoint approach to compute gradients.

# %%
# %matplotlib inline

# %%
import matplotlib
import matplotlib.pyplot as plt
import scipy
from time import clock

# %%
from thetis import *
from firedrake_adjoint import *
from firedrake.adjoint.blocks import GenericSolveBlock

# %%
from adapt_utils.case_studies.tohoku.options import TohokuOptions
from adapt_utils.norms import total_variation
from adapt_utils.misc import gaussian, ellipse

# %% [markdown]
# _[Misc plotting functions]_

# %%
def plot_field(field, figure=None, axes=None, height=5, **kwargs):
    CG1 = field.ufl_element().degree() == 1 and field.ufl_element().family() == 'Lagrange'
    fs_constructor = FunctionSpace if len(field.function_space().shape) == 0 else VectorFunctionSpace
    out = field if CG1 else interpolate(field, fs_constructor(field.function_space().mesh(), "CG", 1))
    
    if figure is None and axes is None:
        figure, axes = plt.subplots(figsize=(height*1.2, height))
    if axes is None:
        axes = plt.gca()
    figure.colorbar(tricontourf(out, levels=50, axes=axes, cmap='coolwarm', **kwargs), ax=axes);
    axes.axis(False);
    axes.set_title(field.dat.name);
    return axes

# %%
def plot_fields(*fields, height=5):
    nfields = len(fields)
    fig, axes = plt.subplots(ncols=nfields, figsize=(height*nfields*1.2, height))
    for i, field in enumerate(fields):
        try:
            plot_field(field, fig, axes[i])
        except AttributeError:
            plot_mesh(field, fig, axes[i])
    return axes

# %%
level = 0
# level = 1
# level = 2

op = TohokuOptions(level=level)
op.gauges.pop('21418')  # This pressure gauge isn't within the domain

mesh = op.default_mesh

boundary_conditions = {
    100: ['freeslip', 'dirichlet'],
    200: ['freeslip'],
    300: ['freeslip'],
}

basis_centres = [(0.7e+06, 4.2e+06), ]

# %% [markdown]
# ### Forward model
#
# As before, consider the shallow water equations linearised about lake at rest:
#
# $$
#     \frac{\partial\mathbf u}{\partial t}+g\nabla\eta+f\widehat{\mathbf z}\times\mathbf u=\boldsymbol0,\qquad
#     \frac{\partial\eta}{\partial t}+\nabla\cdot(b\mathbf u)=0,\qquad
#     \text{in}\quad(0,T]\times\Omega,
# $$
#
# equipped with boundary conditions
#
# $$
#     \mathbf u\cdot\widehat{\mathbf n}|_{\Gamma_{\mathrm{freeslip}}}\equiv0,\qquad
#     \eta|_{\Gamma_D}\equiv0.
# $$
#
# Assume zero initial velocity and expand the initial surface over a radial basis:
#
# $$
#     \mathbf u|_{t=0}\equiv\boldsymbol0,\qquad
#     \eta|_{t=0}=\sum_{k=1}^N m_kg_k,
# $$
#
# where $m_k$ are (constant in space) control parameters and $g_k$ are Gaussians.

# %% [markdown]
# Choose an initial guess for the basis coefficient

# %%
R = FunctionSpace(mesh, "R", 0)
m0 = Function(R).assign(10.0)

# %%
def get_fields(fs):
    elev_space = fs.sub(1)
    b = Function(elev_space, name="Bathymetry (from GEBCO)").assign(op.set_bathymetry(elev_space))
    f = Function(elev_space, name="Coriolis parameter").assign(op.set_coriolis(elev_space))
    g = Constant(op.g)
    return b, f, g

# %% [markdown]
# ### Quantity of Interest
#
# Again, we have the QoI
#
# $$
# J(\mathbf u,\eta)=\frac12\sum_{g\in\mathcal G}\int_0^T\int_\Omega\mathbb1_g\big(\:\eta(x,t)-\eta_g(t)\:\big)^2\;\mathrm dx\;\mathrm dt,
# $$
#
# where $\mathbb1_g$ is an indicator function related to a sufficiently small neighbourhood of gauge $g$.

# %%
def sampled_timeseries(g, sample=1):
    time_prev = 0.0
    num_lines = sum(1 for line in open('resources/gauges/{:s}.dat'.format(g), 'r'))
    t, d, running = [], [], []
    with open('resources/gauges/{:s}.dat'.format(g), 'r') as f:
        for i in range(num_lines):
            time, dat = f.readline().split()
            time, dat = float(time), float(dat)
            if np.isnan(dat):
                continue
            running.append(dat)
            if i % sample == 0 and i > 0:
                t.append(0.5*(time + time_prev))
                d.append(np.mean(running))
                running = 0
                time_prev = time
                running = []
                
    interp = scipy.interpolate.interp1d(t, d, bounds_error=False, fill_value='extrapolate')
    init = interp(0.0)
    
    def shifted(tau):
        return interp(tau) - init
    
    return shifted

# %%
def get_basis_functions(fs, xy_skew=(48e+03, 96e+03), angle=pi/12):
    basis_functions = []
    for loc in basis_centres:
        basis_function = Function(fs)
        psi, phi = basis_function.split()
        phi.interpolate(gaussian([loc + xy_skew, ], fs.mesh(), rotation=angle))
        basis_functions.append(basis_function)
    return basis_functions

# %%
def print_debug(msg, debug=False):
    if debug:
        print(msg)

# %%
def solve_forward(ctrls, gradient=False, debug=True, store_timeseries=False, ext=''):
    print("FORWARD SOLVE FOR GRADIENT CALCULATION" if gradient else "FORWARD SOLVE")
    if isinstance(ctrls, Function):
        ctrls = [ctrls, ]
    
    # --- Setup function spaces
    
    fs = VectorFunctionSpace(mesh, "CG", 2)*FunctionSpace(mesh, "CG", 1)
    P0 = FunctionSpace(mesh, "DG", 0)
    
    # -- Setup fields
    
    b, f, g = get_fields(fs)
    
    # --- Setup PDE
    
    dtc = Constant(op.dt)
    
    u, eta = TrialFunctions(fs)
    z, zeta = TestFunctions(fs)

    q_ = Function(fs)
    u_, eta_ = q_.split()

    a = inner(z, u)*dx + inner(zeta, eta)*dx
    L = inner(z, u_)*dx + inner(zeta, eta_)*dx
    
    n = FacetNormal(mesh)

    def G(uv, elev):
        F = g*inner(z, grad(elev))*dx
        F += f*inner(z, as_vector((-uv[1], uv[0])))*dx
        F += -inner(grad(zeta), b*uv)*dx
        for tag in boundary_conditions:
            if 'freeslip' not in boundary_conditions[tag]:
                F += inner(zeta*n, b*uv)*ds(tag)
        return F

    a += 0.5*dtc*G(u, eta)
    L += -0.5*dtc*G(u_, eta_)

    q = Function(fs)
    u, eta = q.split()

    bcs = []
    for tag in boundary_conditions:
        if 'dirichlet' in boundary_conditions[tag]:
            bcs.append(DirichletBC(fs.sub(1), 0, tag))

    params = {
        "snes_type": "ksponly",
        "ksp_type": "gmres",
        "pc_type": "fieldsplit",
        "pc_fieldsplit_type": "multiplicative",
    }

    problem = LinearVariationalProblem(a, L, q, bcs=bcs)
    solver = LinearVariationalSolver(problem, solver_parameters=params)
    
    # --- Setup initial condition / control
    
    basis_functions = get_basis_functions(fs)
    try:
        assert len(basis_functions) == len(ctrls)
    except AssertionError:
        msg = "Number of basis functions and number of basis coefficients do not match ({:d} vs {:d})"
        raise ValueError(msg.format(len(basis_functions), len(ctrls)))
    q_.project(sum(m_i*phi_i for m_i, phi_i in zip(ctrls, basis_functions)))
    
    # --- Setup QoI
    
    radius = 20.0e+03*pow(0.5, level)  # The finer the mesh, the more precise the indicator region
    for gauge in op.gauges:
        op.gauges[gauge]['indicator'] = interpolate(ellipse([op.gauges[gauge]["coords"] + (radius,), ], mesh), P0)
        op.gauges[gauge]['interpolator'] = sampled_timeseries(gauge, sample=60 if gauge[0] == 'P' else 1)
        if store_timeseries:
            op.gauges[gauge]['timeseries'+ext] = []
            op.gauges[gauge]['diff'+ext] = []
            op.gauges[gauge]['timeseries_smooth'+ext] = []
            op.gauges[gauge]['diff_smooth'+ext] = []
            op.gauges[gauge]['data'] = []
            op.gauges[gauge]['init'] = None
            op.gauges[gauge]['area'] = assemble(op.gauges[gauge]['indicator']*dx, annotate=False)
    times = []
        
    # --- Time integrate
    
    op.end_time = 1440.0
    
    t = 0.0
    iteration = 0
    J = 0
    eta_obs = Constant(0.0)
    weight = Constant(1.0)
    tic = clock()
    msg = "    simulation time {:4.1f} minutes    wallclock time {:4.1f} seconds"
    while t < op.end_time:
        times.append(t)
        if iteration % 48 == 0:
            toc = clock() - tic
            print_debug(msg.format(t/60, toc), debug=debug)
            tic = clock()

        # Solve forward equation at current timestep
        solver.solve()

        # Time integrate QoI
        weight.assign(0.5 if np.allclose(t, 0.0) else 1.0)
        u, eta = q.split()
        for gauge in op.gauges:
            
            # Interpolate observations
            obs = float(op.gauges[gauge]['interpolator'](t))
            eta_obs.assign(obs)
            
            if store_timeseries:
                op.gauges[gauge]['data'].append(obs)
                
                # Point evaluation at gauges
                eta_discrete = eta.at(op.gauges[gauge]["coords"])
                if op.gauges[gauge]['init'] is None:
                    op.gauges[gauge]['init'] = eta_discrete
                eta_discrete -= op.gauges[gauge]['init']
                op.gauges[gauge]['timeseries'+ext].append(eta_discrete)
                
                # Discrete form of error
                diff = 0.5*(eta_discrete - eta_obs.dat.data[0])**2
                op.gauges[gauge]['diff'+ext].append(diff)
            
            # Continuous form of error
            I = op.gauges[gauge]['indicator']
            diff = 0.5*I*(eta - eta_obs)**2
            J += assemble(weight*dtc*diff*dx)
            if store_timeseries:
                A = op.gauges[gauge]['area']
                op.gauges[gauge]['diff_smooth'+ext].append(assemble(diff*dx, annotate=False)/A)
                op.gauges[gauge]['timeseries_smooth'+ext].append(assemble(I*eta_obs*dx, annotate=False)/A)

        # Increment
        q_.assign(q)
        t += op.dt
        iteration += 1

    assert np.allclose(t, op.end_time), print("mismatching end time ({:.2f} vs {:.2f})".format(t, op.end_time))
    toc = clock() - tic
    print_debug(msg.format(t/60, toc), debug=debug)
    print_debug("    Quantity of interest = {:.8e}".format(J), debug=debug)
    
    weight.assign(0.5)
    u, eta = q.split()
    for gauge in op.gauges:
        indicator = op.gauges[gauge]['indicator']

        # Interpolate observations
        obs = float(op.gauges[gauge]['interpolator'](t))
        eta_obs.assign(obs)

        # Continuous form of error
        J += assemble(weight*dtc*0.5*indicator*(eta - eta_obs)**2*dx)
    
    return J, q

# %%
def reduced_functional(m, debug=True, **kwargs):
    J, q = solve_forward(m, debug=debug)
    return ReducedFunctional(J, Control(m), **kwargs)

# %% [markdown]
# Let's take a look at the forward solution.

# %%
tape = get_working_tape()
tape.clear_tape()
m0 = Function(R).assign(10.0)
J, q = solve_forward(m0, store_timeseries=True)
u, eta = q.split()
u.dat.name = "Velocity (initial guess control)"
eta.dat.name = "Elevation (initial guess control)"
plot_fields(u, eta);
# Out:
# FORWARD SOLVE
#     simulation time  0.0 minutes    wallclock time  0.0 seconds
#     simulation time  4.0 minutes    wallclock time 33.3 seconds
#     simulation time  8.0 minutes    wallclock time 32.5 seconds
#     simulation time 12.0 minutes    wallclock time 35.4 seconds
#     simulation time 16.0 minutes    wallclock time 36.9 seconds
#     simulation time 20.0 minutes    wallclock time 32.7 seconds
#     simulation time 24.0 minutes    wallclock time 33.0 seconds
#     Quantity of interest = 1.49686832e+13

# %%
g = compute_gradient(J, Control(m0))

# %% [markdown]
# Let's take a look at the adjoint solution.

# %%
tape = get_working_tape()
blocks = tape.get_blocks()
solve_blocks = [block for block in blocks if isinstance(block, GenericSolveBlock)]
u_star, eta_star = solve_blocks[0].adj_sol.split()
u_star.dat.name = "Adjoint velocity at t=0"
eta_star.dat.name = "Adjoint elevation at t=0"
plot_fields(u_star, eta_star);

# %% [markdown]
# ## Taylor Test
#
# To check that the gradient is consistent, we can apply a Taylor remainder test.
# Denote by $\widehat J=\widehat J(m)$ the reduced functional and consider the first order Taylor remainder
#
# $$
#     T_1(h):=\left|\:\widehat J(m+h\delta m) - \widehat J(m)\:\right|,
# $$
#
# for some search direction $\delta m$ and step length $m$.
# In addition, consider the second order Taylor remainder
#
# $$
#     T_2(h):=\left|\:\widehat J(m+h\delta m) - \widehat J(m) - h\;\mathrm d\widehat J\cdot\delta m\:\right|.
# $$
#
# where we propose that $\mathrm d\widehat J$ is the gradient of $\widehat J$ w.r.t. the control $m$.
# Continuity of the reduced functional implies that $\lim_{h\rightarrow0}T_1(h)=0$ at rate $\mathcal O(h)$.
# Provided that $\mathrm d\widehat J$ is indeed the gradient, we also have that $\lim_{h\rightarrow0}T_2(h)=0$.
# Moreover, we expect that this convergence is achieved at rate $\mathcal O(h^2)$.
#
# The Taylor test simply verifies that the second order convergence is achieved.

# %%
def taylor_test(m_init, h_init=1):
    print(20*"=" + "TAYLOR TEST" + 20*"=")
    tape = get_working_tape()
    tape.clear_tape()
    m = Function(R).assign(m_init)
    
    # Choose a random search direction
    delta_m = np.random.rand(1)
    
    # Evaluate the reduced functional and gradient at the specified control value
    Jm = solve_forward(m)[0]
    print("GRADIENT COMPUTATION")
    dJm = compute_gradient(Jm, Control(m)).dat.data
    m = np.array([m, ])
    tape.clear_tape()
    
    # Check that the Taylor remainders decrease quadratically
    with stop_annotating():
        remainders = np.zeros(3)
        for i in range(3):
            h = h_init*pow(0.5, i)
            print("h = {:.4e}".format(h))
            J_step = solve_forward(m+h*delta_m)[0]
            remainders[i] = abs(J_step - Jm - h*np.dot(dJm, delta_m))
            print("Taylor remainder = {:.4e}".format(remainders[i]))
            if i > 0:
                ratio = remainders[i-1]/remainders[i]
                try:
                    assert ratio > 3.95
                except AssertionError:
                    msg = "Taylor remainders do not decrease quadratically (ratio {:.4e})"
                    raise ConvergenceError(msg.format(ratio))
    print(16*"=" + "TAYLOR TEST PASSED!" + 16*"=")

# %%
taylor_test(4.5)
# Out:
# ====================TAYLOR TEST====================
# FORWARD SOLVE
#     simulation time  0.0 minutes    wallclock time  0.0 seconds
#     simulation time  4.0 minutes    wallclock time 13.6 seconds
#     simulation time  8.0 minutes    wallclock time 13.6 seconds
#     simulation time 12.0 minutes    wallclock time 11.6 seconds
#     simulation time 16.0 minutes    wallclock time 13.9 seconds
#     simulation time 20.0 minutes    wallclock time 13.8 seconds
#     simulation time 24.0 minutes    wallclock time 14.5 seconds
#     Quantity of interest = 1.07522018e+13
# GRADIENT COMPUTATION
# h = 1.0000e+00
# FORWARD SOLVE
#     simulation time  0.0 minutes    wallclock time  0.0 seconds
#     simulation time  4.0 minutes    wallclock time  7.8 seconds
#     simulation time  8.0 minutes    wallclock time  7.6 seconds
#     simulation time 12.0 minutes    wallclock time  7.8 seconds
#     simulation time 16.0 minutes    wallclock time  8.2 seconds
#     simulation time 20.0 minutes    wallclock time  9.0 seconds
#     simulation time 24.0 minutes    wallclock time  8.8 seconds
#     Quantity of interest = 1.07634822e+13
# Taylor remainder = 3.0853e+09
# h = 5.0000e-01
# FORWARD SOLVE
#     simulation time  0.0 minutes    wallclock time  0.0 seconds
#     simulation time  4.0 minutes    wallclock time  7.3 seconds
#     simulation time  8.0 minutes    wallclock time  7.3 seconds
#     simulation time 12.0 minutes    wallclock time  8.5 seconds
#     simulation time 16.0 minutes    wallclock time  8.6 seconds
#     simulation time 20.0 minutes    wallclock time  8.6 seconds
#     simulation time 24.0 minutes    wallclock time  9.3 seconds
#     Quantity of interest = 1.07570734e+13
# Taylor remainder = 7.7132e+08
# h = 2.5000e-01
# FORWARD SOLVE
#     simulation time  0.0 minutes    wallclock time  0.0 seconds
#     simulation time  4.0 minutes    wallclock time  8.3 seconds
#     simulation time  8.0 minutes    wallclock time  7.9 seconds
#     simulation time 12.0 minutes    wallclock time  8.1 seconds
#     simulation time 16.0 minutes    wallclock time  8.4 seconds
#     simulation time 20.0 minutes    wallclock time  8.7 seconds
#     simulation time 24.0 minutes    wallclock time  8.9 seconds
#     Quantity of interest = 1.07544455e+13
# Taylor remainder = 1.9283e+08
# ================TAYLOR TEST PASSED!================

# %% [markdown]
# ## Parameter space exploration
#
# Since we have a one-dimensional control parameter space, we can easily explore the parameter space to see how it looks.

# %%
n = 9
control_values = np.linspace(2.0, 10.0, n)
func_values = np.zeros(n)
with stop_annotating():
    for i, m in enumerate(control_values):
        m0.assign(m)
        func_values[i] = solve_forward(m0, debug=False)[0]
        print("{:2d}: control value {:.4e}  functional value {:.4e}".format(i, m, func_values[i]))
# Out:
# FORWARD SOLVE
#  0: control value 2.0000e+00  functional value 1.1467e+13
# FORWARD SOLVE
#  1: control value 3.0000e+00  functional value 1.0998e+13
# FORWARD SOLVE
#  2: control value 4.0000e+00  functional value 1.0790e+13
# FORWARD SOLVE
#  3: control value 5.0000e+00  functional value 1.0842e+13
# FORWARD SOLVE
#  4: control value 6.0000e+00  functional value 1.1154e+13
# FORWARD SOLVE
#  5: control value 7.0000e+00  functional value 1.1727e+13
# FORWARD SOLVE
#  6: control value 8.0000e+00  functional value 1.2560e+13
# FORWARD SOLVE
#  7: control value 9.0000e+00  functional value 1.3653e+13
# FORWARD SOLVE
#  8: control value 1.0000e+01  functional value 1.5007e+13

# %%
fig, axes = plt.subplots(figsize=(8, 8))

print(func_values)  # We will use these again later

axes.plot(control_values, func_values, '--x')
axes.set_xlabel("Control values");
axes.set_ylabel("Functional values");
# Out:
# [1.14670603e+13 1.09983814e+13 1.07900293e+13 1.08420040e+13
#  1.11543055e+13 1.17269337e+13 1.25598888e+13 1.36531706e+13
#  1.50067792e+13]

# %% [markdown]
# The parameter space for this one dimensional control looks to be a nice convex parabola, which we propose has a minimum in the range $[3, 5]$.
#
# This plot will be very useful in interpreting the progress of the minimisation routine.

# %% [markdown]
# ## Inversion for a single basis function coefficient
#
# Now that we have functions for solving the forward problem and computing the gradient, we can apply a quasi-Newton optimisation method such as BFGS to optimise the control parameter.
# BFGS may be expressed in pseudocode as
#
# * Choose initial guess $m_0$
# * $i:=0$
# * while not converged:
#     - solve forward problem with control $m_i$ to evaluate QoI as $J_i$
#     - solve adjoint problem
#     - compute gradient $g_i$ for control $m_i$
#
#     - Approximate Hessian:
#         * if $i = 0$ then $H_i:=I$
#         * else:
#             - $s := m_i - m_{i-1}$
#             - $y := g_i - g_{i-1}$
#             - $H_i := \left(I - \frac{sy^T}{y^Ts}\right) H_{i-1} \left(I - \frac{ys^T}{y^Ts}\right) + \frac{ss^T}{y^Ts}$
#
#     - compute search direction $p_i := H_ig_i$
#     - compute step length $\alpha_i$ using line search
#     - take step $m_{i+1} := m_i + \alpha_ip_i$
#     - check convergence
#     - $i = i+1$
#
# where $I$ is the identity matrix and each $m_i$ is a vector of control parameters.

# %%
tape = get_working_tape()
tape.clear_tape()

# Create arrays so we can track progress
control_values_opt = []
func_values_opt = []
gradient_values_opt = []

def derivative_cb_post(j, dj, m):
    control_values_opt.append(m)
    func_values_opt.append(j)
    gradient_values_opt.append(dj)
    print("control {:.8e}  functional  {:.8e}  gradient {:.8e}".format(m.dat.data[0], j, dj.dat.data[0]))

# Fairly loose convergence criteria to see quick results
opt_parameters = {
    'maxiter': 5,
    'gtol': 1.0,
}

# Choose initial guess
m = Function(R).assign(10.0)

# Evaluate the reduced functional
J = reduced_functional(m, debug=False, derivative_cb_post=derivative_cb_post)

# Call BFGS
m_opt = minimize(J, method='BFGS', options=opt_parameters)
print("Optimised control parameter = {:.4e}".format(*m_opt.dat.data))
# Out:
# FORWARD SOLVE
# control 1.00000000e+01  functional  1.50067792e+13  gradient 1.48377202e+12
# control 8.99000000e+00  functional  1.36409491e+13  gradient 1.22084196e+12
# control 6.73010333e+00  functional  1.15467342e+13  gradient 6.32530349e+11
# control 4.30034808e+00  functional  1.07782874e+13  gradient 6.03546280e+04
# control 4.30034785e+00  functional  1.07782874e+13  gradient 3.08315817e-03
# control 4.30034806e+00  functional  1.07782874e+13  gradient 5.54125389e+04
# control 4.30034806e+00  functional  1.07782874e+13  gradient 5.53660074e+04
# control 4.30034806e+00  functional  1.07782874e+13  gradient 5.54125335e+04
# control 4.30034806e+00  functional  1.07782874e+13  gradient 5.54125335e+04
# control 4.30034806e+00  functional  1.07782874e+13  gradient 5.53892720e+04
# control 4.30034806e+00  functional  1.07782874e+13  gradient 5.54125289e+04
# control 4.30034806e+00  functional  1.07782874e+13  gradient 5.54125289e+04
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-bb2743ec4fcf> in <module>
#      26 J = reduced_functional(m, debug=False, derivative_cb_post=derivative_cb_post)
#      27
# ---> 28 m_opt = minimize(J, method='BFGS', options=opt_parameters)
#      29 print("Optimised control parameter = {:.4e}".format(*m_opt.dat.data))
#
# ~/software/firedrake-pragmatic/src/pyadjoint/pyadjoint/tape.py in wrapper(*args, **kwargs)
#      44     def wrapper(*args, **kwargs):
#      45         with stop_annotating():
# ---> 46             return function(*args, **kwargs)
#      47
#      48     return wrapper
#
# ~/software/firedrake-pragmatic/src/pyadjoint/pyadjoint/optimization/optimization.py in minimize(rf, method, scale, **kwargs)
#     252         kwargs["method"] = method
#     253
# --> 254     opt = algorithm(rf_np, **kwargs)
#     255
#     256     if len(opt) == 1:
#
# ~/software/firedrake-pragmatic/src/pyadjoint/pyadjoint/optimization/optimization.py in minimize_scipy_generic(rf_np, method, bounds, **kwargs)
#     133         res = scipy_minimize(J, m_global, method=method, bounds=bounds, **kwargs)
#     134     else:
# --> 135         res = scipy_minimize(J, m_global, method=method, **kwargs)
#     136
#     137     rf_np.set_controls(np.array(res["x"]))
#
# ~/software/firedrake-pragmatic/lib/python3.6/site-packages/scipy/optimize/_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     602         return _minimize_cg(fun, x0, args, jac, callback, **options)
#     603     elif meth == 'bfgs':
# --> 604         return _minimize_bfgs(fun, x0, args, jac, callback, **options)
#     605     elif meth == 'newton-cg':
#     606         return _minimize_newtoncg(fun, x0, args, jac, hess, hessp, callback,
#
# ~/software/firedrake-pragmatic/lib/python3.6/site-packages/scipy/optimize/optimize.py in _minimize_bfgs(fun, x0, args, jac, callback, gtol, norm, eps, maxiter, disp, return_all, **unknown_options)
#    1026             alpha_k, fc, gc, old_fval, old_old_fval, gfkp1 = \
#    1027                      _line_search_wolfe12(f, myfprime, xk, pk, gfk,
# -> 1028                                           old_fval, old_old_fval, amin=1e-100, amax=1e100)
#    1029         except _LineSearchError:
#    1030             # Line search failed to find a better solution.
#
# ~/software/firedrake-pragmatic/lib/python3.6/site-packages/scipy/optimize/optimize.py in _line_search_wolfe12(f, fprime, xk, pk, gfk, old_fval, old_old_fval, **kwargs)
#     843     ret = line_search_wolfe1(f, fprime, xk, pk, gfk,
#     844                              old_fval, old_old_fval,
# --> 845                              **kwargs)
#     846
#     847     if ret[0] is not None and extra_condition is not None:
#
# ~/software/firedrake-pragmatic/lib/python3.6/site-packages/scipy/optimize/linesearch.py in line_search_wolfe1(f, fprime, xk, pk, gfk, old_fval, old_old_fval, args, c1, c2, amax, amin, xtol)
#      99     stp, fval, old_fval = scalar_search_wolfe1(
#     100             phi, derphi, old_fval, old_old_fval, derphi0,
# --> 101             c1=c1, c2=c2, amax=amax, amin=amin, xtol=xtol)
#     102
#     103     return stp, fc[0], gc[0], fval, old_fval, gval[0]
#
# ~/software/firedrake-pragmatic/lib/python3.6/site-packages/scipy/optimize/linesearch.py in scalar_search_wolfe1(phi, derphi, phi0, old_phi0, derphi0, c1, c2, amax, amin, xtol)
#     174             alpha1 = stp
#     175             phi1 = phi(stp)
# --> 176             derphi1 = derphi(stp)
#     177         else:
#     178             break
#
# ~/software/firedrake-pragmatic/lib/python3.6/site-packages/scipy/optimize/linesearch.py in derphi(s)
#      88
#      89     def derphi(s):
# ---> 90         gval[0] = fprime(xk + s*pk, *newargs)
#      91         if gradient:
#      92             gc[0] += 1
#
# ~/software/firedrake-pragmatic/lib/python3.6/site-packages/scipy/optimize/optimize.py in function_wrapper(*wrapper_args)
#     325     def function_wrapper(*wrapper_args):
#     326         ncalls[0] += 1
# --> 327         return function(*(wrapper_args + args))
#     328
#     329     return ncalls, function_wrapper
#
# ~/software/firedrake-pragmatic/src/pyadjoint/pyadjoint/optimization/optimization.py in <lambda>(m)
#      64     J = rf_np.__call__
#      65
# ---> 66     dJ = lambda m: rf_np.derivative(m, forget=forget, project=project)
#      67     H = rf_np.hessian
#      68
#
# ~/software/firedrake-pragmatic/src/pyadjoint/pyadjoint/tape.py in wrapper(*args, **kwargs)
#      44     def wrapper(*args, **kwargs):
#      45         with stop_annotating():
# ---> 46             return function(*args, **kwargs)
#      47
#      48     return wrapper
#
# ~/software/firedrake-pragmatic/src/pyadjoint/pyadjoint/reduced_functional_numpy.py in derivative(self, m_array, forget, project)
#      68         # if m_array is not None:
#      69         #    self.__call__(m_array)
# ---> 70         dJdm = self.rf.derivative()
#      71         dJdm = Enlist(dJdm)
#      72
#
# ~/software/firedrake-pragmatic/src/pyadjoint/pyadjoint/reduced_functional.py in derivative(self, options)
#      63                                        options=options,
#      64                                        tape=self.tape,
# ---> 65                                        adj_value=self.scale)
#      66
#      67         # Call callback
#
# ~/software/firedrake-pragmatic/src/pyadjoint/pyadjoint/drivers.py in compute_gradient(J, m, options, tape, adj_value)
#      27     with stop_annotating():
#      28         with tape.marked_nodes(m):
# ---> 29             tape.evaluate_adj(markings=True)
#      30
#      31     grads = [i.get_derivative(options=options) for i in m]
#
# ~/software/firedrake-pragmatic/src/pyadjoint/pyadjoint/tape.py in evaluate_adj(self, last_block, markings)
#     138     def evaluate_adj(self, last_block=0, markings=False):
#     139         for i in range(len(self._blocks) - 1, last_block - 1, -1):
# --> 140             self._blocks[i].evaluate_adj(markings=markings)
#     141
#     142     def evaluate_tlm(self):
#
# ~/software/firedrake-pragmatic/src/pyadjoint/pyadjoint/tape.py in wrapper(*args, **kwargs)
#      44     def wrapper(*args, **kwargs):
#      45         with stop_annotating():
# ---> 46             return function(*args, **kwargs)
#      47
#      48     return wrapper
#
# ~/software/firedrake-pragmatic/src/pyadjoint/pyadjoint/block.py in evaluate_adj(self, markings)
#     125             return
#     126
# --> 127         prepared = self.prepare_evaluate_adj(inputs, adj_inputs, relevant_dependencies)
#     128
#     129         for idx, dep in relevant_dependencies:
#
# ~/software/firedrake-pragmatic/src/pyadjoint/dolfin_adjoint_common/blocks/solving.py in prepare_evaluate_adj(self, inputs, adj_inputs, relevant_dependencies)
#     144
#     145         compute_bdy = self._should_compute_boundary_adjoint(relevant_dependencies)
# --> 146         adj_sol, adj_sol_bdy = self._assemble_and_solve_adj_eq(dFdu_form, dJdu, compute_bdy)
#     147         self.adj_sol = adj_sol
#     148         if self.adj_cb is not None:
#
# ~/software/firedrake-pragmatic/src/pyadjoint/dolfin_adjoint_common/blocks/solving.py in _assemble_and_solve_adj_eq(self, dFdu_adj_form, dJdu, compute_bdy)
#     169
#     170         adj_sol = self.compat.create_function(self.function_space)
# --> 171         self.compat.linalg_solve(dFdu, adj_sol.vector(), dJdu, *self.adj_args, **self.adj_kwargs)
#     172
#     173         adj_sol_bdy = None
#
# ~/software/firedrake-pragmatic/src/firedrake/firedrake/adjoint/solving.py in wrapper(*args, **kwargs)
#      46
#      47         with stop_annotating():
# ---> 48             output = solve(*args, **kwargs)
#      49
#      50         if annotate:
#
# ~/software/firedrake-pragmatic/src/firedrake/firedrake/solving.py in solve(*args, **kwargs)
#     128     else:
#     129         # Solve pre-assembled system
# --> 130         return _la_solve(*args, **kwargs)
#     131
#     132
#
# ~/software/firedrake-pragmatic/src/firedrake/firedrake/solving.py in _la_solve(A, x, b, **kwargs)
#     235
#     236     with dmhooks.add_hooks(dm, solver, appctx=ctx):
# --> 237         solver.solve(x, b)
#     238
#     239
#
# ~/software/firedrake-pragmatic/src/firedrake/firedrake/linear_solver.py in solve(self, x, b)
#     146
#     147         if self.A.has_bcs:
# --> 148             b = self._lifted(b)
#     149
#     150         if self.ksp.getInitialGuessNonzero():
#
# ~/software/firedrake-pragmatic/src/firedrake/firedrake/linear_solver.py in _lifted(self, b)
#     118     def _lifted(self, b):
#     119         u, update, blift = self._rhs
# --> 120         u.dat.zero()
#     121         for bc in self.A.bcs:
#     122             bc.apply(u)
#
# ~/software/firedrake-pragmatic/src/PyOP2/pyop2/base.py in zero(self, subset)
#    2087             raise NotImplementedError("Subsets of mixed sets not implemented")
#    2088         for d in self._dats:
# -> 2089             d.zero()
#    2090
#    2091     @cached_property
#
# ~/software/firedrake-pragmatic/src/PyOP2/pyop2/base.py in zero(self, subset)
#    1570
#    1571             inames = isl.make_zero_and_vars(["i"])
# -> 1572             domain = (inames[0].le_set(inames["i"])) & (inames["i"].lt_set(inames[0] + self.cdim))
#    1573             x = p.Variable("dat")
#    1574             i = p.Variable("i")
#
# ~/software/firedrake-pragmatic/lib/python3.6/site-packages/islpy/__init__.py in expr_like_add(self, other)
#     757         if not isinstance(other, ARITH_CLASSES):
#     758             try:
# --> 759                 other = _number_to_expr_like(self, other)
#     760             except _isl.IslTypeError:
#     761                 return NotImplemented
#
# ~/software/firedrake-pragmatic/lib/python3.6/site-packages/islpy/__init__.py in _number_to_expr_like(template, num)
#     735         if template.get_pieces():
#     736             number_pw_aff = PwAff.empty(template.get_space())
# --> 737             for set, _ in template.get_pieces():
#     738                 number_pw_aff = set.indicator_function().cond(
#     739                         number_aff, number_pw_aff)
#
# ~/software/firedrake-pragmatic/lib/python3.6/site-packages/islpy/__init__.py in pwaff_get_pieces(self)
#     653             result.append(args)
#     654
# --> 655         self.foreach_piece(append_tuple)
#     656         return result
#     657
#
# ~/software/firedrake-pragmatic/lib/python3.6/site-packages/islpy/_isl.py in foreach_piece(self, fn)
#   27030             _result = None
#   27031             with DelayedKeyboardInterrupt():
# > 27032                 _result = lib.isl_pw_aff_foreach_piece(self.data, _cb_fn, ffi.NULL)
#   27033         finally:
#   27034             if _result is None:
#
# ~/software/firedrake-pragmatic/lib/python3.6/site-packages/islpy/_isl.py in __exit__(self, type, value, traceback)
#     155             sys.setswitchinterval(10000000)
#     156
# --> 157         def __exit__(self, type, value, traceback):
#     158             sys.setswitchinterval(self.previous_switch_interval)
#     159 else:
#
# KeyboardInterrupt:

# %%
m_opt = Function(R).assign(4.30034806e+00)

# %% [markdown]
# Let's view the progress of the optimisation routine superimposed on the sample of the parameter space explored previously.

# %%
fig, axes = plt.subplots(figsize=(8, 8))

axes.plot(control_values, func_values, '--x')
ctrl_plot = [ctrl.dat.data[0] for ctrl in control_values_opt]
gradient_plot = [gradient.dat.data[0] for gradient in gradient_values_opt]
axes.plot(ctrl_plot, func_values_opt, 'o', color='r')

delta_m = 0.25
for m, f, g in zip(ctrl_plot, func_values_opt, gradient_plot):
    x = np.array([m - delta_m, m + delta_m])
    axes.plot(x, g*(x-m) + f, '-', color='g')

axes.set_xlabel("Control values");
axes.set_ylabel("Functional values");

# %% [markdown]
# As we would hope, BFGS converges rapidly to the minimiser of the parabola and the gradients generated by the discrete adjoint look consistent with the tangent gradients shown in the plot.
#
# Let's see what the forward solution looks like with the optimised control.

# %%
J, q_opt = solve_forward(m_opt, store_timeseries=True, ext='_opt')
u_opt, eta_opt = q_opt.split()
u_opt.dat.name = "Velocity (optimised control)"
eta_opt.dat.name = "Elevation (optimised control)"
plot_fields(u_opt, eta_opt);
# Out:
# FORWARD SOLVE
#     simulation time  0.0 minutes    wallclock time  0.0 seconds
#     simulation time  4.0 minutes    wallclock time 32.7 seconds
#     simulation time  8.0 minutes    wallclock time 35.5 seconds
#     simulation time 12.0 minutes    wallclock time 38.0 seconds
#     simulation time 16.0 minutes    wallclock time 36.3 seconds
#     simulation time 20.0 minutes    wallclock time 33.1 seconds
#     simulation time 24.0 minutes    wallclock time 32.7 seconds
#     Quantity of interest = 1.07467301e+13

# %%
fig, axes = plt.subplots(nrows=4, ncols=2, figsize=(14, 2*len(op.gauges)))

times = np.linspace(0, op.end_time, int(op.end_time/op.dt))
for i, gauge in enumerate(op.gauges):
    ax = axes[i//2, i%2]
    ax.plot(times/60, op.gauges[gauge]['timeseries'], '--x', label=gauge + ' initial guess')
    ax.plot(times/60, op.gauges[gauge]['timeseries_opt'], '--x', label=gauge + ' optimised')
    ax.plot(times/60, op.gauges[gauge]['data'], '--x', label=gauge + ' data')
    ax.legend(loc='upper right')
    ax.set_xlabel('Time (min)')
    ax.set_ylabel('Elevation (m)')
axes[3, 1].axis('off');

# %%
msg = "total variation for gauge {:s}: before {:.4e}  after {:.4e} reduction  {:.1f}%"

print("Continuous")
for gauge in op.gauges:
    tv = total_variation(op.gauges[gauge]['diff_smooth'])
    tv_opt = total_variation(op.gauges[gauge]['diff_smooth_opt'])
    print(msg.format(gauge, tv, tv_opt, 100*(1-tv_opt/tv)))
    
print("\nDiscrete")
for gauge in op.gauges:
    tv = total_variation(op.gauges[gauge]['diff'])
    tv_opt = total_variation(op.gauges[gauge]['diff_opt'])
    print(msg.format(gauge, tv, tv_opt, 100*(1-tv_opt/tv)))
# Out:
# Continuous
# total variation for gauge P02: before 3.2098e+01  after 2.8364e+01 reduction  11.6%
# total variation for gauge P06: before 2.8979e+01  after 2.7319e+01 reduction  5.7%
# total variation for gauge 801: before 7.3854e+00  after 2.8336e+00 reduction  61.6%
# total variation for gauge 802: before 2.6839e+00  after 4.1164e+00 reduction  -53.4%
# total variation for gauge 803: before 2.5867e+00  after 3.0868e+00 reduction  -19.3%
# total variation for gauge 804: before 9.5363e-01  after 7.8401e-01 reduction  17.8%
# total variation for gauge 806: before 8.2841e-01  after 9.5693e-01 reduction  -15.5%
#
# Discrete
# total variation for gauge P02: before 4.7441e+01  after 3.2899e+01 reduction  30.7%
# total variation for gauge P06: before 2.5481e+01  after 2.6057e+01 reduction  -2.3%
# total variation for gauge 801: before 1.2290e+01  after 2.7899e+00 reduction  77.3%
# total variation for gauge 802: before 2.6409e+00  after 4.0501e+00 reduction  -53.4%
# total variation for gauge 803: before 3.1550e+00  after 1.4898e+00 reduction  52.8%
# total variation for gauge 804: before 1.5721e+00  after 1.1234e+00 reduction  28.5%
# total variation for gauge 806: before 1.5287e+00  after 1.0282e+00 reduction  32.7%

# %% [markdown]
# Clearly, it is going to be extremely difficult to get a good representation of the complex initial free surface displacement due to an earthquake using a single radial basis function.
# We see from the outputs above that in the continuous formulation, any improvements at particular gauges is largely cancelled out by less accurate results at others.
# However, there is a general improvement in the discrete error formulation (which is at the end of the day the one we care about).
#
# In addition to using more basis functions, we propose that using meshes higher up the hierarchy would lead to optimised controls which better approximate the true initial surface.
# Mesh adaptation could also be beneficial, increasing the resolution in critical regions such as near the gauges.
