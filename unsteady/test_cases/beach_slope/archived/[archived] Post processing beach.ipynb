# %%
import pandas as pd
import pylab as plt

# %%
results_02 = pd.read_excel('/Users/mc4117/Documents/adapt_utils/unsteady/test_cases/beach_slope/results_beach.xlsx', sheet_name = '0.2')
results_025 = pd.read_excel('/Users/mc4117/Documents/adapt_utils/unsteady/test_cases/beach_slope/results_beach.xlsx', sheet_name = '0.25_2')
results_05 = pd.read_excel('/Users/mc4117/Documents/adapt_utils/unsteady/test_cases/beach_slope/results_beach.xlsx', sheet_name = '0.5')
results_06 = pd.read_excel('/Users/mc4117/Documents/adapt_utils/unsteady/test_cases/beach_slope/results_beach.xlsx', sheet_name = '0.6')
results_075 = pd.read_excel('/Users/mc4117/Documents/adapt_utils/unsteady/test_cases/beach_slope/results_beach.xlsx', sheet_name = '0.75')
time_output = pd.read_excel('/Users/mc4117/Documents/adapt_utils/unsteady/test_cases/beach_slope/results_beach2.xlsx', sheet_name = 'time_per_movement', header = None)

# %%
# 5; 1; 0

error_list = []
time_list = []

for i in time_output.iloc[0][1:-2]:
    error_list.append(time_output.iloc[2][10])
    time_list.append(time_output.iloc[1][10])
    
timesteps = time_output.iloc[0][1:-2].reset_index(drop = True)
diff_error = time_output.iloc[2][1:-2].reset_index(drop = True)
diff_time = time_output.iloc[1][1:-2].reset_index(drop = True)

fig, ax1 = plt.subplots()


color = 'tab:red'
ax1.set_xlabel('Number of timesteps per mesh movement')
ax1.set_ylabel('Discretisation error', color=color)
#ax1.semilogx(diff_time.columns.values[2:-1], diff_time.iloc[0][2:-1], ':', label = r'$\alpha = 3$', color=color)
ax1.semilogx(timesteps, diff_error, '-o', label = 'Mesh movement', color=color)
#ax1.semilogx(diff_time.columns.values[2:-1], diff_time.iloc[2][2:-1], ':', label = r'$\alpha = 5$', color=color)
ax1.semilogx(timesteps, error_list, '--', label = 'Fixed mesh', color = color)
ax1.tick_params(axis='y', labelcolor=color)
plt.legend(loc = 9, bbox_to_anchor=(0.5, 0.73), title = "Error")
ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('Computational time (s)', color=color)  # we already handled the x-label with ax1
#ax2.semilogx(diff_time.columns.values[2:-1], diff_time.iloc[8][2:-1], ':', label = r'$\alpha = 3$', color=color)
ax2.semilogx(timesteps, diff_time, '-o', label = 'Mesh movement', color=color)
#ax2.semilogx(diff_time.columns.values[2:-1], diff_time.iloc[10][2:-1], ':', label = r'$\alpha = 5$', color=color)
ax2.semilogx(timesteps, time_list, '--', label = 'Fixed mesh',  color = color)
ax2.tick_params(axis='y', labelcolor=color)

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.legend(loc = 9, bbox_to_anchor=(0.5, 0.95), title = "Cost")
plt.show()

# %%
# 7; 0; 1

error_list = []
time_list = []

for i in time_output.iloc[6][1:-1]:
    error_list.append(time_output.iloc[8][11])
    time_list.append(time_output.iloc[7][11])
    
timesteps = time_output.iloc[6][1:-1].reset_index(drop = True)
diff_error = time_output.iloc[8][1:-1].reset_index(drop = True)
diff_time = time_output.iloc[7][1:-1].reset_index(drop = True)

fig, ax1 = plt.subplots()


color = 'tab:red'
ax1.set_xlabel('Number of timesteps per mesh movement')
ax1.set_ylabel('Discretisation error', color=color)
ax1.semilogx(timesteps, diff_error, '-o', label = 'Mesh movement', color=color)
ax1.semilogx(timesteps, error_list, '--', label = 'Fixed mesh', color = color)
ax1.tick_params(axis='y', labelcolor=color)
plt.legend(loc = 9, bbox_to_anchor=(0.5, 0.73), title = "Error")
ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('Computational time (s)', color=color)  # we already handled the x-label with ax1
ax2.semilogx(timesteps, diff_time, '-o', label = 'Mesh movement', color=color)
ax2.semilogx(timesteps, time_list, '--', label = 'Fixed mesh',  color = color)
ax2.tick_params(axis='y', labelcolor=color)

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.legend(loc = 9, bbox_to_anchor=(0.5, 0.95), title = "Cost")
plt.show()

# %%
plt.semilogy(results_02[results_02['beta']==1][results_02['gamma']==0]['alpha'][:-1], results_02[results_02['beta']==1][results_02['gamma']==0][72][:-1], color = 'black', label = r'$\Delta x = 5; \beta = 1; \gamma = 0$')
plt.semilogy(results_02[results_02['beta']==0][results_02['gamma']==1]['alpha'], results_02[results_02['beta']==0][results_02['gamma']==1][72], color = 'orange', label = r'$\Delta x = 5; \beta = 0; \gamma = 1$')
plt.semilogy(results_02[results_02['beta']==1][results_02['gamma']==1]['alpha'][:-1], results_02[results_02['beta']==1][results_02['gamma']==1][72][:-1], color = 'red', label = r'$\Delta x = 5; \beta = 1; \gamma = 1$')
plt.xlim([0, 15])
plt.xlabel(r"$\alpha$")
plt.ylabel("L2 error norm")
plt.legend(loc = 10, bbox_to_anchor=(1.2, 0.5))
plt.grid()
#plt.show()

plt.semilogy(results_025[results_025['beta']==1][results_025['gamma']==0]['alpha'][:-1], results_025[results_025['beta']==1][results_025['gamma']==0][72][:-1], color = 'black', label = r'$\Delta x = 4; \beta = 1; \gamma = 0$')
plt.semilogy(results_025[results_025['beta']==0][results_025['gamma']==1]['alpha'][:-1], results_025[results_025['beta']==0][results_025['gamma']==1][72][:-1], color = 'orange', label = r'$\Delta x = 4; \beta = 0; \gamma = 1$')
plt.semilogy(results_025[results_025['beta']==1][results_025['gamma']==1]['alpha'][:-1], results_025[results_025['beta']==1][results_025['gamma']==1][72][:-1], color = 'red', label = r'$\Delta x = 4; \beta = 1; \gamma = 1$')
plt.xlim([0, 15])
plt.xlabel(r"$\alpha$")
plt.ylabel("L2 error norm")
plt.legend(loc = 10, bbox_to_anchor=(1.2, 0.5))
plt.grid()
#plt.show()

plt.semilogy(results_05[results_05['beta']==1][results_05['gamma']==0]['alpha'], results_05[results_05['beta']==1][results_05['gamma']==0][72], color = 'black', label = r'$\Delta x = 2; \beta = 1; \gamma = 0$')
plt.semilogy(results_05[results_05['beta']==0][results_05['gamma']==1]['alpha'], results_05[results_05['beta']==0][results_05['gamma']==1][72], color = 'orange', label = r'$\Delta x = 2; \beta = 0; \gamma = 1$')
plt.semilogy(results_05[results_05['beta']==1][results_05['gamma']==1]['alpha'], results_05[results_05['beta']==1][results_05['gamma']==1][72], color = 'red', label = r'$\Delta x = 2; \beta = 1; \gamma = 1$')
plt.xlim([0, 15])
plt.xlabel(r"$\alpha$")
plt.ylabel("L2 error norm")
plt.legend(loc = 10, bbox_to_anchor=(1.2, 0.5))
plt.grid()
#plt.show()

plt.semilogy(results_06[results_06['beta']==1][results_06['gamma']==0]['alpha'], results_06[results_06['beta']==1][results_06['gamma']==0][72], color = 'black', label = r'$\Delta x = 5/3; \beta = 1; \gamma = 0$')
plt.semilogy(results_06[results_06['beta']==0][results_06['gamma']==1]['alpha'], results_06[results_06['beta']==0][results_06['gamma']==1][72], color = 'orange', label = r'$\Delta x = 5/3; \beta = 0; \gamma = 1$')
plt.semilogy(results_06[results_06['beta']==1][results_06['gamma']==1]['alpha'], results_06[results_06['beta']==1][results_06['gamma']==1][72], color = 'red', label = r'$\Delta x = 5/3; \beta = 1; \gamma = 1$')
plt.xlim([0, 15])
plt.xlabel(r"$\alpha$")
plt.ylabel("L2 error norm")
plt.legend(loc = 10, bbox_to_anchor=(1.2, 0.5))
plt.grid()
#plt.show()

plt.semilogy(results_075[results_075['beta']==1][results_075['gamma']==0]['alpha'], results_075[results_075['beta']==1][results_075['gamma']==0][72], color = 'black', label = r'$\Delta x = 4/3; \beta = 1; \gamma = 0$')
plt.semilogy(results_075[results_075['beta']==0][results_075['gamma']==1]['alpha'], results_075[results_075['beta']==0][results_075['gamma']==1][72], color = 'orange', label = r'$\Delta x = 4/3; \beta = 0; \gamma = 1$')
plt.semilogy(results_075[results_075['beta']==1][results_075['gamma']==1]['alpha'], results_075[results_075['beta']==1][results_075['gamma']==1][72], color = 'red', label = r'$\Delta x = 4/3; \beta = 1; \gamma = 1$')
plt.xlim([0, 15])
plt.xlabel(r"$\alpha$")
plt.ylabel("L2 error norm")
plt.legend(loc = 10, bbox_to_anchor=(1.2, 0.5))
plt.grid()
#plt.show()
# Out:
# /Users/mc4117/firedrake2/firedrake/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# /Users/mc4117/firedrake2/firedrake/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# /Users/mc4117/firedrake2/firedrake/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/mc4117/firedrake2/firedrake/lib/python3.7/site-packages/ipykernel_launcher.py:11: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   # This is added back by InteractiveShellApp.init_path()
# ...

# %%
import pylab as plt

fig, ((ax1, ax2, ax3), (ax4, ax5, ax6)) = plt.subplots(2, 3, figsize=(11,8))

ax1.plot(results_02[results_02['beta']==1][results_02['gamma']==0]['alpha'][:-1], results_02[results_02['beta']==1][results_02['gamma']==0][72][:-1], color = 'black', label = r'$\Delta x = 5; \beta = 1; \gamma = 0$')
ax1.plot(results_02[results_02['beta']==0][results_02['gamma']==1]['alpha'], results_02[results_02['beta']==0][results_02['gamma']==1][72], color = 'orange', label = r'$\Delta x = 5; \beta = 0; \gamma = 1$')
ax1.plot(results_02[results_02['beta']==1][results_02['gamma']==1]['alpha'][:-1], results_02[results_02['beta']==1][results_02['gamma']==1][72][:-1], color = 'red', label = r'$\Delta x = 5; \beta = 1; \gamma = 1$')
ax1.set_xlim([0, 12])
ax1.set_xlabel(r"$\mu$")
ax1.set_ylabel("L2 error norm")
ax1.set_title(r'$\Delta x = 5m$')
ax1.grid()


ax2.plot(results_025[results_025['beta']==1][results_025['gamma']==0]['alpha'][:-1], results_025[results_025['beta']==1][results_025['gamma']==0][72][:-1], color = 'black', label = r'$\Delta x = 4; \beta = 1; \gamma = 0$')
ax2.plot(results_025[results_025['beta']==0][results_025['gamma']==1]['alpha'][:-1], results_025[results_025['beta']==0][results_025['gamma']==1][72][:-1], color = 'orange', label = r'$\Delta x = 4; \beta = 0; \gamma = 1$')
ax2.plot(results_025[results_025['beta']==1][results_025['gamma']==1]['alpha'][:-1], results_025[results_025['beta']==1][results_025['gamma']==1][72][:-1], color = 'red', label = r'$\Delta x = 4; \beta = 1; \gamma = 1$')
ax2.set_xlim([0, 12])
ax2.set_xlabel(r"$\mu$")
ax2.set_ylabel("L2 error norm")
ax2.set_title(r'$\Delta x = 4m$')
ax2.grid()

ax3.plot(results_05[results_05['beta']==1][results_05['gamma']==0]['alpha'], results_05[results_05['beta']==1][results_05['gamma']==0][72], color = 'black', label = r'$\Delta x = 2; \beta = 1; \gamma = 0$')
ax3.plot(results_05[results_05['beta']==0][results_05['gamma']==1]['alpha'], results_05[results_05['beta']==0][results_05['gamma']==1][72], color = 'orange', label = r'$\Delta x = 2; \beta = 0; \gamma = 1$')
ax3.plot(results_05[results_05['beta']==1][results_05['gamma']==1]['alpha'], results_05[results_05['beta']==1][results_05['gamma']==1][72], color = 'red', label = r'$\Delta x = 2; \beta = 1; \gamma = 1$')
ax3.set_xlim([0, 12])
ax3.set_xlabel(r"$\mu$")
ax3.set_ylabel("L2 error norm")
ax3.set_title(r'$\Delta x = 2m$')
ax3.grid()

ax4.plot(results_06[results_06['beta']==1][results_06['gamma']==0]['alpha'], results_06[results_06['beta']==1][results_06['gamma']==0][72], color = 'black', label = r'$\Delta x = 5/3; \beta = 1; \gamma = 0$')
ax4.plot(results_06[results_06['beta']==0][results_06['gamma']==1]['alpha'], results_06[results_06['beta']==0][results_06['gamma']==1][72], color = 'orange', label = r'$\Delta x = 5/3; \beta = 0; \gamma = 1$')
ax4.plot(results_06[results_06['beta']==1][results_06['gamma']==1]['alpha'], results_06[results_06['beta']==1][results_06['gamma']==1][72], color = 'red', label = r'$\Delta x = 5/3; \beta = 1; \gamma = 1$')
ax4.set_xlim([0, 12])
ax4.set_xlabel(r"$\mu$")
ax4.set_ylabel("L2 error norm")
ax4.set_title(r'$\Delta x = 5/3m$')
ax4.grid()

ax5.plot(results_075[results_075['beta']==1][results_075['gamma']==0]['alpha'], results_075[results_075['beta']==1][results_075['gamma']==0][72], color = 'black', label = r'$\beta = \mu; \alpha = 0$')
ax5.plot(results_075[results_075['beta']==0][results_075['gamma']==1]['alpha'], results_075[results_075['beta']==0][results_075['gamma']==1][72], color = 'orange', label = r'$\beta = 0; \alpha = \mu$')
ax5.plot(results_075[results_075['beta']==1][results_075['gamma']==1]['alpha'], results_075[results_075['beta']==1][results_075['gamma']==1][72], color = 'red', label = r'$\beta = \mu; \alpha = \mu$')
ax5.set_xlim([0, 12])
ax5.set_xlabel(r"$\mu$")
ax5.set_ylabel("L2 error norm")
ax5.set_title(r'$\Delta x = 4/3m$')
ax5.grid()

ax6.set_xlim([0, 12])
ax6.set_xlabel(r"$\mu$")
ax6.set_ylabel("L2 error norm")
ax6.set_title(r'$\Delta x = 1m$')
ax6.grid()
ax6.legend(loc = 10, bbox_to_anchor=(1.4, 1), title = 'Colour key')
fig.tight_layout()
plt.show()
# Out:
# /Users/mc4117/firedrake2/firedrake/lib/python3.7/site-packages/ipykernel_launcher.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """
# /Users/mc4117/firedrake2/firedrake/lib/python3.7/site-packages/ipykernel_launcher.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# /Users/mc4117/firedrake2/firedrake/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   import sys
# /Users/mc4117/firedrake2/firedrake/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   from ipykernel import kernelapp as app
# /Users/mc4117/firedrake2/firedrake/lib/python3.7/site-packages/ipykernel_launcher.py:16: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   app.launch_new_instance()
# ...

# %%
import pylab as plt

fig, ((ax1, ax2, ax3), (ax4, ax5, ax6)) = plt.subplots(2, 3, figsize=(11,8))

ax1.plot(results_02[results_02['beta_2']==1][results_02['gamma_2']==0]['alpha_2'], results_02[results_02['beta_2']==1][results_02['gamma_2']==0][648], color = 'black', label = r'$\Delta x = 5; \beta = \mu; \alpha = 0$')
ax1.plot(results_02[results_02['beta_2']==0][results_02['gamma_2']==1]['alpha_2'], results_02[results_02['beta_2']==0][results_02['gamma_2']==1][648], color = 'orange', label = r'$\Delta x = 5; \beta = 0; \gamma = 1$')
ax1.plot(results_02[results_02['beta_2']==1][results_02['gamma_2']==1]['alpha_2'], results_02[results_02['beta_2']==1][results_02['gamma_2']==1][648], color = 'red', label = r'$\Delta x = 5; \beta = 1; \gamma = 1$')
ax1.set_xlim([0, 17])
ax1.set_xlabel(r"$\mu$")
ax1.set_ylabel("L2 error norm")
ax1.set_title(r'$\Delta x = 5m$')
ax1.grid()


ax2.plot(results_025[results_025['beta_2']==1][results_025['gamma_2']==0]['alpha_2'], results_025[results_025['beta_2']==1][results_025['gamma_2']==0][648], color = 'black', label = r'$\Delta x = 4; \beta = 1; \gamma = 0$')
ax2.plot(results_025[results_025['beta_2']==0][results_025['gamma_2']==1]['alpha_2'], results_025[results_025['beta_2']==0][results_025['gamma_2']==1][648], color = 'orange', label = r'$\Delta x = 4; \beta = 0; \gamma = 1$')
ax2.plot(results_025[results_025['beta_2']==1][results_025['gamma_2']==1]['alpha_2'], results_025[results_025['beta_2']==1][results_025['gamma_2']==1][648], color = 'red', label = r'$\Delta x = 4; \beta = 1; \gamma = 1$')
ax2.set_xlim([0, 17])
ax2.set_xlabel(r"$\mu$")
ax2.set_ylabel("L2 error norm")
ax2.set_title(r'$\Delta x = 4m$')
ax2.grid()

ax3.plot(results_05[results_05['beta_2']==1][results_05['gamma_2']==0]['alpha_2'], results_05[results_05['beta_2']==1][results_05['gamma_2']==0][648], color = 'black', label = r'$\Delta x = 2; \beta = 1; \gamma = 0$')
ax3.plot(results_05[results_05['beta_2']==0][results_05['gamma_2']==1]['alpha_2'], results_05[results_05['beta_2']==0][results_05['gamma_2']==1][648], color = 'orange', label = r'$\Delta x = 2; \beta = 0; \gamma = 1$')
ax3.plot(results_05[results_05['beta_2']==1][results_05['gamma_2']==1]['alpha_2'], results_05[results_05['beta_2']==1][results_05['gamma_2']==1][648], color = 'red', label = r'$\Delta x = 2; \beta = 1; \gamma = 1$')
ax3.set_xlim([0, 17])
ax3.set_xlabel(r"$\mu$")
ax3.set_ylabel("L2 error norm")
ax3.set_title(r'$\Delta x = 2m$')
ax3.grid()

ax4.plot(results_06[results_06['beta_2']==1][results_06['gamma_2']==0]['alpha_2'], results_06[results_06['beta_2']==1][results_06['gamma_2']==0][648], color = 'black', label = r'$\Delta x = 5/3; \beta = 1; \gamma = 0$')
ax4.plot(results_06[results_06['beta_2']==0][results_06['gamma_2']==1]['alpha_2'], results_06[results_06['beta_2']==0][results_06['gamma_2']==1][648], color = 'orange', label = r'$\Delta x = 5/3; \beta = 0; \gamma = 1$')
ax4.plot(results_06[results_06['beta_2']==1][results_06['gamma_2']==1]['alpha_2'], results_06[results_06['beta_2']==1][results_06['gamma_2']==1][648], color = 'red', label = r'$\Delta x = 5/3; \beta = 1; \gamma = 1$')
ax4.set_xlim([0, 17])
ax4.set_xlabel(r"$\mu$")
ax4.set_ylabel("L2 error norm")
ax4.set_title(r'$\Delta x = 5/3m$')
ax4.grid()

ax5.plot(results_075[results_075['beta_2']==1][results_075['gamma_2']==0]['alpha_2'], results_075[results_075['beta_2']==1][results_075['gamma_2']==0][648], color = 'black', label = r'$\beta = 1; \gamma = 0$')
ax5.plot(results_075[results_075['beta_2']==0][results_075['gamma_2']==1]['alpha_2'].drop(4)[0:3], results_075[results_075['beta_2']==0][results_075['gamma_2']==1][648].drop(4)[0:3], color = 'orange', label = r'$\beta = 0; \gamma = 1$')
ax5.plot(results_075[results_075['beta_2']==1][results_075['gamma_2']==1]['alpha_2'], results_075[results_075['beta_2']==1][results_075['gamma_2']==1][648], color = 'red', label = r'$\beta = 1; \gamma = 1$')
ax5.set_xlim([0, 17])
ax5.set_xlabel(r"$\mu$")
ax5.set_ylabel("L2 error norm")
ax5.set_title(r'$\Delta x = 4/3m$')
ax5.grid()

ax6.set_xlim([0, 15])
ax6.set_xlabel(r"$\mu$")
ax6.set_ylabel("L2 error norm")
ax6.set_title(r'$\Delta x = 1m$')
ax6.grid()
ax6.legend(loc = 10, bbox_to_anchor=(1.4, 1), title = 'Colour key')
ax6.legend(loc = 10, bbox_to_anchor=(1.4, 1), title = 'Colour key')
fig.tight_layout()
plt.show()
# Out:
# /Users/mc4117/firedrake2/firedrake/lib/python3.7/site-packages/ipykernel_launcher.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """
# /Users/mc4117/firedrake2/firedrake/lib/python3.7/site-packages/ipykernel_launcher.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# /Users/mc4117/firedrake2/firedrake/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   import sys
# /Users/mc4117/firedrake2/firedrake/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   from ipykernel import kernelapp as app
# /Users/mc4117/firedrake2/firedrake/lib/python3.7/site-packages/ipykernel_launcher.py:16: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   app.launch_new_instance()
# ...
