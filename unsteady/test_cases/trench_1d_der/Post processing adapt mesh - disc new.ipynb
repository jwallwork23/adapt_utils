# %%
import pandas as pd
import pylab as plt
import numpy as np

import matplotlib

font = {'size'   : 12}

matplotlib.rc('font', **font)

# %%
results_01 = pd.read_excel('results.xls', sheet_name = '0.1')
results_0125 = pd.read_excel('results.xls', sheet_name = '0.125')
results_025 = pd.read_excel('results.xls', sheet_name = '0.25')
results_04 = pd.read_excel('results.xls', sheet_name = '0.4')
results_05 = pd.read_excel('results.xls', sheet_name = '0.5')
results_08 = pd.read_excel('results.xls', sheet_name = '0.8')

# %%
fig, ((ax6, ax5, ax4), (ax3, ax2, ax1)) = plt.subplots(2, 3, figsize=(13,9))
ax1.plot(results_08[results_08['beta']==0]['alpha'][:4], results_08[results_08['beta']==0]['disc new'][:4], 'o-', color = 'black', label = r'$\beta = 0$')
#ax1.plot(results_08[results_08['beta']==0.5]['alpha'][:5], results_08[results_08['beta']==0.5]['error'][:5], 'o-', color = 'orange')
ax1.plot(results_08[results_08['beta']==1.0]['alpha'][:6], results_08[results_08['beta']==1.0]['disc new'][:6],  'o-', color = 'red', label = r'$\beta = \alpha$')
ax1.set_xlabel(r"$\alpha$")
ax1.set_ylabel("Pointwise L2 error norm")
ax1.set_title(r'64 mesh elements in $x$-direction')
ax1.legend(loc = 10, bbox_to_anchor=(1.4, 1), title = 'Colour key')
ax1.grid()

ax2.plot(results_05[results_05['beta']==0]['alpha'][:6], results_05[results_05['beta']==0]['disc new'][:6], 'o-', color = 'black', label = r'$\beta = 0$')
#ax2.plot(results_05[results_05['beta']==0.5]['alpha'], results_05[results_05['beta']==0.5]['error'],'o-', color = 'orange', label = r'$\beta = 0.5$')
ax2.plot(results_05[results_05['beta']==1.0]['alpha'][:6], results_05[results_05['beta']==1.0]['disc new'][:6], 'o-',  color = 'red', label = r'$\beta = 1$')
ax2.set_xlabel(r"$\alpha$")
ax2.set_title(r'40 mesh elements in $x$-direction')
ax2.grid()

ax3.plot(results_04[results_04['beta']==0]['alpha'][:6], results_04[results_04['beta']==0]['disc new'][:6], 'o-', color = 'black', label = r'$\beta = 0$')
#ax3.plot(results_04[results_04['beta']==0.5]['alpha'], results_04[results_04['beta']==0.5]['error'], 'o-', color = 'orange', label = r'$\beta = 0.5$')
ax3.plot(results_04[results_04['beta']==1.0]['alpha'][:6], results_04[results_04['beta']==1.0]['disc new'][:6], 'o-', color = 'red', label = r'$\beta = 1$')
ax3.set_xlabel(r"$\alpha$")
ax3.set_title(r'32 mesh elements in $x$-direction')
ax3.grid()

ax4.plot(results_025[results_025['beta']==0]['alpha'][:6], results_025[results_025['beta']==0]['disc new'][:6], 'o-', color = 'black', label = r'$\beta = 0$')
#ax4.plot(results_025[results_025['beta']==0.5]['alpha'], results_025[results_025['beta']==0.5]['error'],'o-', color = 'orange', label = r'$\beta = 0.5$')
ax4.plot(results_025[results_025['beta']==1.0]['alpha'][:6], results_025[results_025['beta']==1.0]['disc new'][:6], 'o-', color = 'red', label = r'$\beta = 1$')
ax4.set_xlabel(r"$\alpha$")
ax4.set_ylabel("Pointwise L2 error norm")
ax4.set_title(r'20 mesh elements in $x$-direction')
ax4.grid()

ax5.plot(results_0125[results_0125['beta']==0]['alpha'][:6], results_0125[results_0125['beta']==0]['disc new'][:6], 'o-', color = 'black', label = r'$\beta = 0$')
#ax5.plot(results_0125[results_0125['beta']==0.5]['alpha'], results_0125[results_0125['beta']==0.5]['error'], 'o-', color = 'orange', label = r'$\beta = 0.5$')
ax5.plot(results_0125[results_0125['beta']==1.0]['alpha'][:6], results_0125[results_0125['beta']==1.0]['disc new'][:6], 'o-', color = 'red', label = r'$\beta = 1$')
ax5.set_xlabel(r"$\alpha$")
ax5.set_title(r'10 mesh elements in $x$-direction')
#ax5.legend()
ax5.grid()


ax6.plot(results_01[results_01['beta']==0]['alpha'][:6], results_01[results_01['beta']==0]['disc new'][:6], 'o-', color = 'black', label = r'$\beta = 0$')
#ax6.plot(results_01[results_01['beta']==0.5]['alpha'], results_01[results_01['beta']==0.5]['error'], 'o-', color = 'orange', label = r'$\beta = \frac{1}{2}\alpha$')
ax6.plot(results_01[results_01['beta']==1.0]['alpha'][:6], results_01[results_01['beta']==1.0]['disc new'][:6], 'o-', color = 'red', label = r'$\beta = \alpha$')
ax6.set_xlabel(r"$\alpha$")
ax6.set_title(r'8 mesh elements in $x$-direction')
ax6.grid()
fig.tight_layout()
plt.show()

# %%
fig, ((ax1, ax2, ax3), (ax4, ax5, ax6)) = plt.subplots(2, 3, figsize=(13,9))
ax1.plot(results_08[results_08['beta']==0]['alpha'][:4], results_08[results_08['beta']==0]['exp error'][:4], 'o-', color = 'black')
#ax1.plot(results_08[results_08['beta']==0.5]['alpha'][:5], results_08[results_08['beta']==0.5]['exp error'][:5], 'o-', color = 'orange')
ax1.plot(results_08[results_08['beta']==1.0]['alpha'][:6], results_08[results_08['beta']==1.0]['exp error'][:6], 'o-', color = 'red')
ax1.set_xlabel(r"$\alpha$")
ax1.set_ylabel("Pointwise L2 error norm")
ax1.set_title(r'64 mesh elements in $x$-direction')
ax1.grid()

ax2.plot(results_05[results_05['beta']==0]['alpha'][:6], results_05[results_05['beta']==0]['exp error'][:6], 'o-', color = 'black', label = r'$\beta = 0$')
#ax2.plot(results_05[results_05['beta']==0.5]['alpha'], results_05[results_05['beta']==0.5]['exp error'], 'o-', color = 'orange', label = r'$\beta = 0.5$')
ax2.plot(results_05[results_05['beta']==1.0]['alpha'][:6], results_05[results_05['beta']==1.0]['exp error'][:6], 'o-',  color = 'red', label = r'$\beta = 1$')
ax2.set_xlabel(r"$\alpha$")
ax2.set_title(r'40 mesh elements in $x$-direction')
ax2.grid()

ax3.plot(results_04[results_04['beta']==0]['alpha'][:6], results_04[results_04['beta']==0]['exp error'][:6], 'o-', color = 'black', label = r'$\beta = 0$')
#ax3.plot(results_04[results_04['beta']==0.5]['alpha'], results_04[results_04['beta']==0.5]['exp error'], 'o-',  color = 'orange', label = r'$\beta = 0.5$')
ax3.plot(results_04[results_04['beta']==1.0]['alpha'][:6], results_04[results_04['beta']==1.0]['exp error'][:6], 'o-', color = 'red', label = r'$\beta = 1$')
ax3.set_xlabel(r"$\alpha$")
ax3.set_title(r'32 mesh elements in $x$-direction')
ax3.grid()

ax4.plot(results_025[results_025['beta']==0]['alpha'][:6], results_025[results_025['beta']==0]['exp error'][:6], 'o-', color = 'black', label = r'$\beta = 0$')
#ax4.plot(results_025[results_025['beta']==0.5]['alpha'], results_025[results_025['beta']==0.5]['exp error'], 'o-', color = 'orange', label = r'$\beta = 0.5$')
ax4.plot(results_025[results_025['beta']==1.0]['alpha'][:6], results_025[results_025['beta']==1.0]['exp error'][:6], 'o-', color = 'red', label = r'$\beta = 1$')
ax4.set_xlabel(r"$\alpha$")
ax4.set_ylabel("Pointwise L2 error norm")
ax4.set_title(r'20 mesh elements in $x$-direction')
ax4.grid()

ax5.plot(results_0125[results_0125['beta']==0]['alpha'][:6], results_0125[results_0125['beta']==0]['exp error'][:6], 'o-', color = 'black', label = r'$\beta = 0$')
#ax5.plot(results_0125[results_0125['beta']==0.5]['alpha'], results_0125[results_0125['beta']==0.5]['exp error'], 'o-', color = 'orange', label = r'$\beta = 0.5$')
ax5.plot(results_0125[results_0125['beta']==1.0]['alpha'][:6], results_0125[results_0125['beta']==1.0]['exp error'][:6], 'o-', color = 'red', label = r'$\beta = 1$')
ax5.set_xlabel(r"$\alpha$")
ax5.set_title(r'10 mesh elements in $x$-direction')
ax5.grid()


ax6.plot(results_01[results_01['beta']==0]['alpha'][:6], results_01[results_01['beta']==0]['exp error'][:6], 'o-', color = 'black', label = r'$\beta = 0$')
#ax6.plot(results_01[results_01['beta']==0.5]['alpha'], results_01[results_01['beta']==0.5]['exp error'], 'o-', color = 'orange', label = r'$\beta = \frac{1}{2}\alpha$')
ax6.plot(results_01[results_01['beta']==1.0]['alpha'][:6], results_01[results_01['beta']==1.0]['exp error'][:6], 'o-', color = 'red', label = r'$\beta = \alpha$')
ax6.set_xlabel(r"$\alpha$")
ax6.set_title(r'8 mesh elements in $x$-direction')
ax6.grid()
ax6.legend(loc = 10, bbox_to_anchor=(1.4, 1), title = 'Colour key')
fig.tight_layout()
plt.show()

# %%
results_fixed = pd.read_excel('results.xls', sheet_name = 'fixed', index_col = 0)

# %%
from matplotlib.ticker import ScalarFormatter, FormatStrFormatter


fixed_mesh = results_fixed.loc['fixed disc new'][:6]
fixed_exp = results_fixed.loc['fixed exp'][:6]

min_mesh = results_fixed.loc['opt disc new'][:6]
min_exp = results_fixed.loc['min exp'][:6]

gen_mesh = results_fixed.loc['gen disc new'][:6]
gen_exp = results_fixed.loc['gen exp'][:6]

no_elem = results_fixed.loc['no elem'][:6]

fig, ax = plt.subplots()
ax.loglog(no_elem, fixed_mesh, '*-', label = 'Fixed mesh')
ax.loglog(no_elem, gen_mesh, '*-', label = 'General parameters')
ax.loglog(no_elem, min_mesh, '*--', label = 'Optimum parameters')
ax.set_xticks([10, 20, 30, 40, 60])
ax.set_xticklabels([10, 20, 30, 40, 60])
ax.set_yticks([0.001, 0.01])
ax.set_yticklabels([0.001, 0.01])
ax.set_xlabel(r'Number of mesh elements in $x$-direction')
ax.set_ylabel("Pointwise L2 error norm")
plt.grid()
plt.legend()
plt.show()

fig1, ax1 = plt.subplots()
ax1.plot(no_elem, fixed_exp, '*-', label = 'Fixed mesh')
ax1.plot(no_elem, gen_exp, '*-', label = 'General parameters')
ax1.plot(no_elem, min_exp, '*--', label = 'Optimum parameters')
ax1.set_xticks([10, 20, 30, 40, 60])
ax1.set_xticklabels([10, 20, 30, 40, 60])
ax1.set_xlabel(r'Number of mesh elements in $x$-direction')
ax1.set_ylabel("Pointwise L2 error norm")
plt.legend()
plt.grid()
plt.show()

# %%
no_elem = results_fixed.loc['no elem'][:8]
fixed_mesh = results_fixed.loc['fixed disc new'][:8]
logx = np.log([16/i for i in no_elem])
log_error = np.log(fixed_mesh)
poly = np.polyfit(logx, log_error, 1)
print(poly[0])
# Out:
# 1.6573357011169843

# %%
fig, ax = plt.subplots()
ax.loglog(no_elem, fixed_mesh, label = 'Fixed mesh')
ax.scatter([no_elem[i] for i in [3, 5, 7]], [fixed_mesh[i] for i in [3, 5, 7]], label = '__no_label__')
ax.scatter([no_elem[i] for i in [1, 2, 4, 6]], [fixed_mesh[i] for i in [1, 2, 4, 6]], label = '__no_label__')
ax.scatter(no_elem[0], fixed_mesh[0], label = '__no_label__')

ax.loglog([8, 10, 20, 32, 40, 64, 80, 160], [i**(-2) for i in [8, 10, 20, 32, 40, 64, 80, 160]], 'k--', label = '2nd order')
ax.set_xticks([10, 20, 30, 40, 60, 100, 160])
ax.set_xticklabels([10, 20, 30, 40, 60, 100, 160])
ax.set_xlabel(r'Number of mesh elements in $x$-direction')
ax.set_ylabel("Pointwise L2 error norm")
plt.legend()
plt.show()

# %%
fixed_exp = results_fixed.loc['fixed exp'][:8]

fig, ax = plt.subplots()
ax.loglog(no_elem, fixed_exp, label = 'Fixed mesh')
ax.scatter([no_elem[i] for i in [3, 5, 7]], [fixed_exp[i] for i in [3, 5, 7]], label = '__no_label__')
ax.scatter([no_elem[i] for i in [1, 2, 4, 6]], [fixed_exp[i] for i in [1, 2, 4, 6]], label = '__no_label__')
ax.scatter(no_elem[0], fixed_exp[0], label = '__no_label__')

ax.set_xlabel(r'Number of mesh elements in $x$-direction')
ax.set_ylabel("Pointwise L2 error norm")
ax.set_xticks([10, 20, 30, 40, 60, 100, 160])
ax.set_xticklabels([10, 20, 30, 40, 60, 100, 160])
plt.legend()
plt.show()

# %%
fig, ax = plt.subplots()
ax.loglog(no_elem, fixed_mesh, label = 'Fixed discretisation error')
ax.loglog(no_elem, fixed_exp, 'red', label = 'Fixed total error')
ax.scatter([no_elem[i] for i in [3, 5, 7]], [fixed_mesh[i] for i in [3, 5, 7]], label = '__no_label__')
ax.scatter([no_elem[i] for i in [1, 2, 4, 6]], [fixed_mesh[i] for i in [1, 2, 4, 6]], label = '__no_label__')
ax.scatter(no_elem[0], fixed_mesh[0], label = '__no_label__')

ax.loglog([8, 10, 20, 32, 40, 64, 80, 160], [i**(-2) for i in [8, 10, 20, 32, 40, 64, 80, 160]], 'k--', label = '2nd order')
ax.set_xticks([10, 20, 30, 40, 60, 100, 160])
ax.set_xticklabels([10, 20, 30, 40, 60, 100, 160])
ax.set_xlabel(r'Number of mesh elements in $x$-direction')
ax.set_ylabel("Pointwise L2 error norm")
plt.legend()
plt.show()
