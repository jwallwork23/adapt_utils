# %%
import pandas as pd
import pylab as plt
import numpy as np

import matplotlib

font = {'size'   : 12}

matplotlib.rc('font', **font)

# %%
results = pd.read_excel('trench_slant_res.xls', sheet_name = 'Sheet2')

# %%
res_310 = results[results['alpha'] == 3.0][results['beta'] == 1.0][results['gamma'] == 0.0].reset_index(drop=True)
res_301 = results[results['alpha'] == 3.0][results['beta'] == 0.0][results['gamma'] == 1.0].reset_index(drop=True)
res_311 = results[results['alpha'] == 3.0][results['beta'] == 1.0][results['gamma'] == 1.0].reset_index(drop=True)

res_510 = results[results['alpha'] == 5.0][results['beta'] == 1.0][results['gamma'] == 0.0].reset_index(drop=True)
res_501 = results[results['alpha'] == 5.0][results['beta'] == 0.0][results['gamma'] == 1.0].reset_index(drop=True)
res_511 = results[results['alpha'] == 5.0][results['beta'] == 1.0][results['gamma'] == 1.0].reset_index(drop=True)

res_fixed = results[results['alpha'] == 0.0]
# Out:
# <ipython-input-3-ded73571526f>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   res_310 = results[results['alpha'] == 3.0][results['beta'] == 1.0][results['gamma'] == 0.0].reset_index(drop=True)
# <ipython-input-3-ded73571526f>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   res_310 = results[results['alpha'] == 3.0][results['beta'] == 1.0][results['gamma'] == 0.0].reset_index(drop=True)
# <ipython-input-3-ded73571526f>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   res_301 = results[results['alpha'] == 3.0][results['beta'] == 0.0][results['gamma'] == 1.0].reset_index(drop=True)
# <ipython-input-3-ded73571526f>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   res_301 = results[results['alpha'] == 3.0][results['beta'] == 0.0][results['gamma'] == 1.0].reset_index(drop=True)
# ...

# %%
res_510
# Out:
#    Unnamed: 0  Unnamed: 1  no_elem  alpha  beta  gamma     error   Unnamed: 7  \
# 0       0.100         0.1      8.0    5.0   1.0    0.0  0.043913  1215.794756
# 1       0.125         0.4     10.0    5.0   1.0    0.0  0.022675  1263.883907
# 2       0.250         0.4     20.0    5.0   1.0    0.0  0.011727  1310.452459
# 3       0.400         0.4     32.0    5.0   1.0    0.0  0.008861  1364.757753
# 4       0.500         0.5     40.0    5.0   1.0    0.0  0.006477  1429.698340
# 5       0.800         0.8     64.0    5.0   1.0    0.0  0.004619  1810.110791
#
#    Unnamed: 8  Unnamed: 9  Unnamed: 10 Unnamed: 11 Unnamed: 12
# 0         NaN         NaN          NaN         NaN         NaN
# 1         NaN         NaN          NaN         NaN         NaN
# 2         NaN         NaN          NaN         NaN         NaN
# 3         NaN         NaN          NaN         NaN         NaN
# 4         NaN         NaN          NaN         NaN         NaN
# ...

# %%
fig, ax = plt.subplots()
ax.semilogy(res_fixed['no_elem'][:2], res_fixed['error'][:2], label = 'fixed')
ax.semilogy(res_310['no_elem'][:2], res_310['error'][:2], 'r^', label = r"$\alpha =0, \beta = 3$")
ax.semilogy(res_301['no_elem'][:2], res_301['error'][:2], 'g^', label = r"$\alpha =3, \beta = 0$")
ax.semilogy(res_311['no_elem'][:2], res_311['error'][:2], 'b^', label = r"$\alpha =3, \beta = 3$")
ax.semilogy(res_510['no_elem'][:2], res_510['error'][:2], 'r*', label = r"$\alpha =0, \beta = 5$")
ax.semilogy(res_501['no_elem'][:2], res_501['error'][:2], 'g*', label = r"$\alpha =5, \beta = 0$")
ax.semilogy(res_511['no_elem'][:2], res_511['error'][:2], 'b*', label = r"$\alpha =5, \beta = 5$")
plt.xlabel('Number of mesh elements in x-direction')
plt.ylabel('L2 error norm')
ax.set_xticks([8, 9, 10])
ax.set_yticks([0.02, 0.03, 0.04, 0.05])
ax.set_yticklabels([0.02, 0.03, 0.04, 0.05])
#plt.legend(ncol = 2, fontsize = 11, loc = 3)
plt.grid()
plt.show()

# %%
fig, ax = plt.subplots()

ax.semilogy(res_fixed['no_elem'][2:4], res_fixed['error'][2:4], label = 'fixed')
ax.semilogy(res_310['no_elem'][2:4], res_310['error'][2:4], 'r^', label = r"$\alpha =0, \beta = 3$")
ax.semilogy(res_301['no_elem'][2:4], res_301['error'][2:4], 'g^', label = r"$\alpha =3, \beta = 0$")
ax.semilogy(res_311['no_elem'][2:4], res_311['error'][2:4], 'b^', label = r"$\alpha =3, \beta = 3$")
ax.semilogy(res_510['no_elem'][2:4], res_510['error'][2:4], 'r*', label = r"$\alpha =0, \beta = 5$")
ax.semilogy(res_501['no_elem'][2:4], res_501['error'][2:4], 'g*', label = r"$\alpha =5, \beta = 0$")
ax.semilogy(res_511['no_elem'][2:4], res_511['error'][2:4], 'b*', label = r"$\alpha =5, \beta = 5$")
ax.set_xticks([20, 25, 32])
ax.set_yticks([0.01, 0.0105, 0.011, 0.0115, 0.012])
ax.set_yticklabels([0.01, 0.0105, 0.011, 0.0115, 0.012])
ax.set_xlabel('Number of mesh elements in x-direction')
ax.set_ylabel('L2 error norm')
#plt.legend(ncol = 2, fontsize = 11, loc = 3)
plt.grid()
plt.show()

# %%
fig, ax = plt.subplots()

ax.semilogy(res_fixed['no_elem'][4:], res_fixed['error'][4:], label = 'fixed')
ax.semilogy(res_310['no_elem'][4:], res_310['error'][4:], 'r^', label = r"$\alpha =0, \beta = 3$")
ax.semilogy(res_301['no_elem'][4:], res_301['error'][4:], 'g^', label = r"$\alpha =3, \beta = 0$")
ax.semilogy(res_311['no_elem'][4:], res_311['error'][4:], 'b^', label = r"$\alpha =3, \beta = 3$")
ax.semilogy(res_510['no_elem'][4:], res_510['error'][4:], 'r*', label = r"$\alpha =0, \beta = 5$")
ax.semilogy(res_501['no_elem'][4:], res_501['error'][4:], 'g*', label = r"$\alpha =5, \beta = 0$")
ax.semilogy(res_511['no_elem'][4:], res_511['error'][4:], 'b*', label = r"$\alpha =5, \beta = 5$")
ax.set_xticks([40, 50, 64])
ax.set_yticks([5e-3, 6e-3, 7e-3, 8e-3, 9e-3])
ax.set_xlabel('Number of mesh elements in x-direction')
ax.set_ylabel('L2 error norm')
plt.legend(ncol = 2, fontsize = 11, loc = 1, bbox_to_anchor=(1.75, 1))
plt.grid()
plt.show()

# %%
fig, ax = plt.subplots()
ax.semilogy(res_fixed['no_elem'][:3], res_fixed['error'][:3], label = 'fixed')
ax.semilogy(res_310['no_elem'][:3], res_310['error'][:3], 'r^', label = r"$\alpha =0, \beta = 3$")
ax.semilogy(res_301['no_elem'][:3], res_301['error'][:3], 'g^', label = r"$\alpha =3, \beta = 0$")
ax.semilogy(res_311['no_elem'][:3], res_311['error'][:3], 'b^', label = r"$\alpha =3, \beta = 3$")
ax.semilogy(res_510['no_elem'][:3], res_510['error'][:3], 'r*', label = r"$\alpha =0, \beta = 5$")
ax.semilogy(res_501['no_elem'][:3], res_501['error'][:3], 'g*', label = r"$\alpha =5, \beta = 0$")
ax.semilogy(res_511['no_elem'][:3], res_511['error'][:3], 'b*', label = r"$\alpha =5, \beta = 5$")
plt.xlabel('Number of mesh elements in x-direction')
plt.ylabel('L2 error norm')
ax.set_xticks([8, 10, 20])
ax.set_yticks([0.01, 0.02, 0.03, 0.04, 0.06])
ax.set_yticklabels([0.01, 0.02, 0.03, 0.04, 0.06])
plt.legend(ncol = 2, fontsize = 10.5) #, loc = 1, bbox_to_anchor=(1.75, 1))
plt.grid()
plt.show()

# %%
fig, ax = plt.subplots()
ax.semilogy(res_fixed['no_elem'][3:], res_fixed['error'][3:], label = 'fixed')
ax.semilogy(res_310['no_elem'][3:], res_310['error'][3:], 'r^', label = r"$\alpha =0, \beta = 3$")
ax.semilogy(res_301['no_elem'][3:], res_301['error'][3:], 'g^', label = r"$\alpha =3, \beta = 0$")
ax.semilogy(res_311['no_elem'][3:], res_311['error'][3:], 'b^', label = r"$\alpha =3, \beta = 3$")
ax.semilogy(res_510['no_elem'][3:], res_510['error'][3:], 'r*', label = r"$\alpha =0, \beta = 5$")
ax.semilogy(res_501['no_elem'][3:], res_501['error'][3:], 'g*', label = r"$\alpha =5, \beta = 0$")
ax.semilogy(res_511['no_elem'][3:], res_511['error'][3:], 'b*', label = r"$\alpha =5, \beta = 5$")
plt.xlabel('Number of mesh elements in x-direction')
plt.ylabel('L2 error norm')
#ax.set_xticks([8, 10, 20])
ax.set_yticks([0.005, 0.006, 0.007, 0.008, 0.009])
ax.set_yticklabels([0.005, 0.006, 0.007, 0.008, 0.009])
plt.legend(ncol = 2, fontsize = 10.5) #, loc = 1, bbox_to_anchor=(1.75, 1))
plt.grid()
plt.show()

# %%
from matplotlib.ticker import ScalarFormatter, FormatStrFormatter

mov_elem = []
mov_mesh = []
mov_elem.append(res_501['no_elem'][0])
mov_mesh.append(res_501['error'][0])
mov_elem.append(res_501['no_elem'][1])
mov_mesh.append(res_501['error'][1])
mov_elem.append(res_501['no_elem'][2])
mov_mesh.append(res_501['error'][2])
mov_elem.append(res_511['no_elem'][3])
mov_mesh.append(res_511['error'][3])
mov_elem.append(res_510['no_elem'][4])
mov_mesh.append(res_510['error'][4])
mov_elem.append(res_510['no_elem'][5])
mov_mesh.append(res_510['error'][5])

fig, ax = plt.subplots()
ax.loglog(mov_elem, res_fixed['error'], '*-', label = 'Fixed mesh')
ax.loglog(mov_elem, mov_mesh2, '*-', label = 'General parameters')
ax.set_xticks([10, 20, 30, 40, 60])
ax.set_xticklabels([10, 20, 30, 40, 60])
ax.set_yticks([4e-3, 6e-3, 1e-2, 2e-2, 4e-2])
ax.set_yticklabels([4e-3, 6e-3, 1e-2, 2e-2, 4e-2])
ax.set_xlabel(r'Number of mesh elements in $x$-direction')
ax.set_ylabel("L2 error norm")
plt.legend()
plt.grid()
plt.show()

# %%
mov_mesh
# Out:
# [0.0373513116701761,
#  0.0239053791047935,
#  0.0110223618970654,
#  0.00871837473711707,
#  0.00647657019902231,
#  0.00461853554692999]
