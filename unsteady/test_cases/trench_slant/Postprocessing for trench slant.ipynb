# %%
import pandas as pd
results_01 = pd.read_excel('/Users/mc4117/Documents/adapt_utils/unsteady/test_cases/trench_slant/results.xlsx', sheet_name = '0.1')
results_02 = pd.read_excel('/Users/mc4117/Documents/adapt_utils/unsteady/test_cases/trench_slant/results.xlsx', sheet_name = '0.2')
results_04 = pd.read_excel('/Users/mc4117/Documents/adapt_utils/unsteady/test_cases/trench_slant/results.xlsx', sheet_name = '0.4')
results_05 = pd.read_excel('/Users/mc4117/Documents/adapt_utils/unsteady/test_cases/trench_slant/results.xlsx', sheet_name = '0.5')
results_08 = pd.read_excel('/Users/mc4117/Documents/adapt_utils/unsteady/test_cases/trench_slant/results.xlsx', sheet_name = '0.8')
results_10 = pd.read_excel('/Users/mc4117/Documents/adapt_utils/unsteady/test_cases/trench_slant/results.xlsx', sheet_name = '1.0')
results_16 = pd.read_excel('/Users/mc4117/Documents/adapt_utils/unsteady/test_cases/trench_slant/results.xlsx', sheet_name = '1.6')

# %%
import pylab as plt

plt.semilogy(results_16[results_16['beta']==0]['alpha'][:-1], results_16[results_16['beta']==0]['error'][:-1], color = 'black', label = r'$\Delta x = 0.125; \beta = 0$')
plt.semilogy(results_16[results_16['beta']==0.5]['alpha'][:-1], results_16[results_16['beta']==0.5]['error'][:-1], color = 'orange', label = r'$\Delta x = 0.125; \beta = 0.5$')
plt.semilogy(results_16[results_16['beta']==1.0]['alpha'][:-1], results_16[results_16['beta']==1.0]['error'][:-1], color = 'red', label = r'$\Delta x = 0.125; \beta = 1$')
plt.show()
plt.semilogy(results_10[results_10['beta']==0]['alpha'][:6], results_10[results_10['beta']==0]['error'][:6], '--', color = 'black', label = r'$\Delta x = 0.2; \beta = 0$')
plt.semilogy(results_10[results_10['beta']==0.5]['alpha'][:6], results_10[results_10['beta']==0.5]['error'][:6], '--', color = 'orange', label = r'$\Delta x = 0.2; \beta = 0.5$')
plt.semilogy(results_10[results_10['beta']==1.0]['alpha'][:6], results_10[results_10['beta']==1.0]['error'][:6], '--',color = 'red', label = r'$\Delta x = 0.2; \beta = 1$')
plt.xlim([0, 10])
plt.xlabel(r"$\alpha$")
plt.ylabel("L2 error norm")
plt.legend(loc = 10, bbox_to_anchor=(1.2, 0.5))
plt.grid()
plt.show()

plt.semilogy(results_08[results_08['beta']==0]['alpha'][0:6], results_08[results_08['beta']==0]['error'][0:6],  color = 'black', label = r'$\Delta x = 0.25; \beta = 0$')
plt.semilogy(results_08[results_08['beta']==0.5]['alpha'][0:6], results_08[results_08['beta']==0.5]['error'][0:6],  color = 'orange', label = r'$\Delta x = 0.25; \beta = 0.5$')
plt.semilogy(results_08[results_08['beta']==1.0]['alpha'][0:6], results_08[results_08['beta']==1.0]['error'][0:6], color = 'red', label = r'$\Delta x = 0.25; \beta = 1$')
plt.show()
plt.semilogy(results_05[results_05['beta']==0]['alpha'][:6], results_05[results_05['beta']==0]['error'][:6], '--', color = 'black', label = r'$\Delta x = 0.4; \beta = 0$')
plt.semilogy(results_05[results_05['beta']==0.5]['alpha'][:6], results_05[results_05['beta']==0.5]['error'][:6], '--', color = 'orange', label = r'$\Delta x = 0.4; \beta = 0.5$')
plt.semilogy(results_05[results_05['beta']==1.0]['alpha'][:6], results_05[results_05['beta']==1.0]['error'][:6], '--', color = 'red', label = r'$\Delta x = 0.4; \beta = 1$')
plt.show()
plt.semilogy(results_04[results_04['beta']==0]['alpha'][:6], results_04[results_04['beta']==0]['error'][:6], ':', color = 'black', label = r'$\Delta x = 0.5; \beta = 0$')
plt.semilogy(results_04[results_04['beta']==0.5]['alpha'][:6], results_04[results_04['beta']==0.5]['error'][:6], ':', color = 'orange', label = r'$\Delta x = 0.5; \beta = 0.5$')
plt.semilogy(results_04[results_04['beta']==1.0]['alpha'][:6], results_04[results_04['beta']==1.0]['error'][:6],':', color = 'red', label = r'$\Delta x = 0.5; \beta = 1$')
plt.xlim([0, 10])
plt.xlabel(r"$\alpha$")
plt.ylabel("L2 error norm")
plt.legend(loc = 10, bbox_to_anchor=(1.2, 0.5))
plt.grid()
plt.show()

plt.plot(results_02[results_02['beta']==0]['alpha'][:6], results_02[results_02['beta']==0]['error'][:6]/results_02[results_02['alpha']==0]['error'][0], color = 'black', label = r'$\Delta x = 1; \beta = 0$')
plt.plot(results_02[results_02['beta']==0.5]['alpha'][:6], results_02[results_02['beta']==0.5]['error'][:6]/results_02[results_02['alpha']==0]['error'][0], color = 'orange', label = r'$\Delta x = 1; \beta = 0.5$')
plt.plot(results_02[results_02['beta']==1.0]['alpha'][:6], results_02[results_02['beta']==1.0]['error'][:6]/results_02[results_02['alpha']==0]['error'][0], color = 'red', label = r'$\Delta x = 1; \beta = 1$')

plt.plot(results_01[results_01['beta']==0]['alpha'][:6], results_01[results_01['beta']==0]['error'][:6]/results_01[results_01['alpha']==0]['error'][0], '--', color = 'black', label = r'$\Delta x = 2; \beta = 0$')
plt.plot(results_01[results_01['beta']==0.5]['alpha'][:6], results_01[results_01['beta']==0.5]['error'][:6]/results_01[results_01['alpha']==0]['error'][0], '--', color = 'orange', label = r'$\Delta x = 2; \beta = 0.5$')
plt.plot(results_01[results_01['beta']==1.0]['alpha'][:6], results_01[results_01['beta']==1.0]['error'][:6]/results_01[results_01['alpha']==0]['error'][0], '--', color = 'red', label = r'$\Delta x = 2; \beta = 1$')
plt.legend(loc = 10, bbox_to_anchor=(1.2, 0.5))
plt.xlim([0, 10])
plt.xlabel(r"$\alpha$")
plt.ylabel("L2 error norm")
plt.grid()
plt.show()

# %%
import pylab as plt

fig, ((ax1, ax2, ax3), (ax4, ax5, ax6)) = plt.subplots(2, 3, figsize=(11,8))

ax1.plot(results_16[results_16['beta']==0]['alpha'][:-1], results_16[results_16['beta']==0]['error'][:-1], color = 'black', label = r'$\Delta x = 0.125m$')#'\beta = 0$')
ax1.plot(results_16[results_16['beta']==0.5]['alpha'][:-1], results_16[results_16['beta']==0.5]['error'][:-1], color = 'orange', label = '_nolegend_')#r'$\beta = 0.5$')
ax1.plot(results_16[results_16['beta']==1.0]['alpha'][:-1], results_16[results_16['beta']==1.0]['error'][:-1], color = 'red', label = '_nolegend_') #= r'$\beta = 1$')
#ax1.set_xlim([0, 10])
#ax1.set_xlabel(r"$\alpha$")
#ax1.set_ylabel("L2 error norm")
#ax1.set_title(r'$\Delta x = 0.125m$')
#ax1.grid()

ax1.plot(results_10[results_10['beta']==0]['alpha'][:6], results_10[results_10['beta']==0]['error'][:6], ':', color = 'black', label = r'$\Delta x = 0.2m$') #r'$\beta = 0$')
ax1.plot(results_10[results_10['beta']==0.5]['alpha'][:6], results_10[results_10['beta']==0.5]['error'][:6], ':', color = 'orange', label = '_nolegend_') #r'$\beta = 0.5$')
ax1.plot(results_10[results_10['beta']==1.0]['alpha'][:6], results_10[results_10['beta']==1.0]['error'][:6], ':', color = 'red', label = '_nolegend_') #r'$\beta = 1$')
ax1.set_xlim([0, 10])
ax1.set_xlabel(r"$\alpha$")
ax1.set_ylabel("L2 error norm")
ax1.set_title(r'Fine $\Delta x$')
ax1.legend()
ax1.grid()

ax2.plot(results_08[results_08['beta']==0]['alpha'][0:6], results_08[results_08['beta']==0]['error'][0:6],  color = 'black', label = r'$\beta = 0$')
ax2.plot(results_08[results_08['beta']==0.5]['alpha'][0:6], results_08[results_08['beta']==0.5]['error'][0:6],  color = 'orange', label = r'$\beta = 0.5$')
ax2.plot(results_08[results_08['beta']==1.0]['alpha'][0:6], results_08[results_08['beta']==1.0]['error'][0:6], color = 'red', label = r'$\beta = 1$')
ax2.set_xlim([0, 10])
ax2.set_xlabel(r"$\alpha$")
ax2.set_ylabel("L2 error norm")
ax2.set_title(r'$\Delta x = 0.25m$')
#ax2.legend()
ax2.grid()

ax3.plot(results_05[results_05['beta']==0]['alpha'][:6], results_05[results_05['beta']==0]['error'][:6], color = 'black', label = r'$\beta = 0$')
ax3.plot(results_05[results_05['beta']==0.5]['alpha'][:6], results_05[results_05['beta']==0.5]['error'][:6], color = 'orange', label = r'$\beta = 0.5$')
ax3.plot(results_05[results_05['beta']==1.0]['alpha'][:6], results_05[results_05['beta']==1.0]['error'][:6],  color = 'red', label = r'$\beta = 1$')
ax3.set_xlim([0, 10])
ax3.set_xlabel(r"$\alpha$")
ax3.set_ylabel("L2 error norm")
ax3.set_title(r'$\Delta x = 0.4m$')
#ax3.legend()
ax3.grid()

ax4.plot(results_04[results_04['beta']==0]['alpha'][:6], results_04[results_04['beta']==0]['error'][:6], color = 'black', label = r'$\beta = 0$')
ax4.plot(results_04[results_04['beta']==0.5]['alpha'][:6], results_04[results_04['beta']==0.5]['error'][:6],  color = 'orange', label = r'$\beta = 0.5$')
ax4.plot(results_04[results_04['beta']==1.0]['alpha'][:6], results_04[results_04['beta']==1.0]['error'][:6], color = 'red', label = r'$\beta = 1$')
ax4.set_xlim([0, 10])
ax4.set_xlabel(r"$\alpha$")
ax4.set_ylabel("L2 error norm")
ax4.set_title(r'$\Delta x = 0.5m$')
#ax4.legend()
ax4.grid()

ax5.plot(results_02[results_02['beta']==0]['alpha'][:6], results_02[results_02['beta']==0]['error'][:6], color = 'black', label = r'$\beta = 0$')
ax5.plot(results_02[results_02['beta']==0.5]['alpha'][:6], results_02[results_02['beta']==0.5]['error'][:6], color = 'orange', label = r'$\beta = 0.5$')
ax5.plot(results_02[results_02['beta']==1.0]['alpha'][:6], results_02[results_02['beta']==1.0]['error'][:6], color = 'red', label = r'$\beta = 1$')
ax5.set_xlim([0, 10])
ax5.set_xlabel(r"$\alpha$")
ax5.set_ylabel("L2 error norm")
ax5.set_title(r'$\Delta x = 1m$')
#ax5.legend()
ax5.grid()


ax6.plot(results_01[results_01['beta']==0]['alpha'][:6], results_01[results_01['beta']==0]['error'][:6], color = 'black', label = r'$\beta = 0$')
ax6.plot(results_01[results_01['beta']==0.5]['alpha'][:6], results_01[results_01['beta']==0.5]['error'][:6], color = 'orange', label = r'$\beta = \frac{1}{2}\alpha$')
ax6.plot(results_01[results_01['beta']==1.0]['alpha'][:6], results_01[results_01['beta']==1.0]['error'][:6], color = 'red', label = r'$\beta = \alpha$')
ax6.set_xlim([0, 10])
ax6.set_xlabel(r"$\alpha$")
ax6.set_ylabel("L2 error norm")
ax6.set_title(r'$\Delta x = 2m$')
ax6.grid()
ax6.legend(loc = 10, bbox_to_anchor=(1.4, 1), title = 'Colour key')
fig.tight_layout()
plt.show()

# %%
from matplotlib import cm
import numpy as np

start = 0.0
stop = 1.0
number_of_lines= 7
cm_subsection = np.linspace(start, stop, number_of_lines) 

colors = [ cm.viridis(x) for x in cm_subsection ]

plt.plot(results_16[results_16['alpha']==2]['beta'], results_16[results_16['alpha']==2]['error'], color = colors[0], label = r'$\Delta x = 0.125m; \alpha = 2$')
plt.plot(results_16[results_16['alpha']==4]['beta'], results_16[results_16['alpha']==4]['error'], color = colors[1], label = r'$\Delta x = 0.125m; \alpha = 4$')
plt.plot(results_16[results_16['alpha']==6]['beta'][1:], results_16[results_16['alpha']==6]['error'][1:], color = colors[2], label = r'$\Delta x = 0.125m; \alpha = 6$')
plt.plot(results_16[results_16['alpha']==8]['beta'][1:], results_16[results_16['alpha']==8]['error'][1:], color = colors[3], label = r'$\Delta x = 0.125m; \alpha = 8$')
plt.plot(results_16[results_16['alpha']==10]['beta'][1:], results_16[results_16['alpha']==10]['error'][1:], color = colors[4], label = r'$\Delta x = 0.125m; \alpha = 10$')

plt.plot(results_10[results_10['alpha']==2]['beta'], results_10[results_10['alpha']==2]['error'], color = colors[0], label = r'$\Delta x = 0.2m; \alpha = 2$')
plt.plot(results_10[results_10['alpha']==4]['beta'], results_10[results_10['alpha']==4]['error'], color = colors[1], label = r'$\Delta x = 0.2m; \alpha = 4$')
plt.plot(results_10[results_10['alpha']==6]['beta'][1:], results_10[results_10['alpha']==6]['error'][1:], color = colors[2], label = r'$\Delta x = 0.2m; \alpha = 6$')
plt.plot(results_10[results_10['alpha']==8]['beta'][1:], results_10[results_10['alpha']==8]['error'][1:], color = colors[3], label = r'$\Delta x = 0.2m; \alpha = 8$')
plt.plot(results_10[results_10['alpha']==10]['beta'][1:], results_10[results_10['alpha']==10]['error'][1:], color = colors[4], label = r'$\Delta x = 0.2m; \alpha = 10$')
plt.xlabel(r"$\beta$")
plt.ylabel("L2 error norm")
plt.legend(loc = 10, ncol =2)
plt.show()

plt.plot(results_08[results_08['alpha']==2]['beta'], results_08[results_08['alpha']==2]['error'], '--', color = colors[0], label = r'$\Delta x = 0.25m; \alpha = 2$')
plt.plot(results_08[results_08['alpha']==4]['beta'], results_08[results_08['alpha']==4]['error'],'--', color = colors[1], label = r'$\Delta x = 0.25m; \alpha = 4$')
plt.plot(results_08[results_08['alpha']==6]['beta'], results_08[results_08['alpha']==6]['error'], '--', color = colors[2], label = r'$\Delta x = 0.25m; \alpha = 6$')
plt.plot(results_08[results_08['alpha']==8]['beta'], results_08[results_08['alpha']==8]['error'], '--', color = colors[3], label = r'$\Delta x = 0.25m; \alpha = 8$')
plt.plot(results_08[results_08['alpha']==10]['beta'], results_08[results_08['alpha']==10]['error'], '--', color = colors[4], label = r'$\Delta x = 0.25m; \alpha = 10$')

plt.plot(results_05[results_05['alpha']==2]['beta'], results_05[results_05['alpha']==2]['error'], '--', color = colors[0], label = r'$\Delta x = 0.4m; \alpha = 2$')
plt.plot(results_05[results_05['alpha']==4]['beta'], results_05[results_05['alpha']==4]['error'],'--', color = colors[1], label = r'$\Delta x = 0.4m; \alpha = 4$')
plt.plot(results_05[results_05['alpha']==6]['beta'], results_05[results_05['alpha']==6]['error'], '--', color = colors[2], label = r'$\Delta x = 0.4m; \alpha = 6$')
plt.plot(results_05[results_05['alpha']==8]['beta'], results_05[results_05['alpha']==8]['error'], '--', color = colors[3], label = r'$\Delta x = 0.4m; \alpha = 8$')
plt.plot(results_05[results_05['alpha']==10]['beta'], results_05[results_05['alpha']==10]['error'], '--', color = colors[4], label = r'$\Delta x = 0.4m; \alpha = 10$')

plt.plot(results_04[results_04['alpha']==2]['beta'], results_04[results_04['alpha']==2]['error'], '--', color = colors[0], label = r'$\Delta x = 0.5m; \alpha = 2$')
plt.plot(results_04[results_04['alpha']==4]['beta'], results_04[results_04['alpha']==4]['error'],'--', color = colors[1], label = r'$\Delta x = 0.5m; \alpha = 4$')
plt.plot(results_04[results_04['alpha']==6]['beta'], results_04[results_04['alpha']==6]['error'], '--', color = colors[2], label = r'$\Delta x = 0.5m; \alpha = 6$')
plt.plot(results_04[results_04['alpha']==8]['beta'], results_04[results_04['alpha']==8]['error'], '--', color = colors[3], label = r'$\Delta x = 0.5m; \alpha = 8$')
plt.plot(results_04[results_04['alpha']==10]['beta'], results_04[results_04['alpha']==10]['error'], '--', color = colors[4], label = r'$\Delta x = 0.5m; \alpha = 10$')


plt.xlabel(r"$\beta$")
plt.ylabel("L2 error norm")
plt.legend(loc = 10, ncol =2)
plt.show()

plt.plot(results_02[results_02['alpha']==2]['beta'], results_02[results_02['alpha']==2]['error'], '--', color = colors[0], label = r'$\Delta x = 1m; \alpha = 2$')
plt.plot(results_02[results_02['alpha']==4]['beta'], results_02[results_02['alpha']==4]['error'],'--', color = colors[1], label = r'$\Delta x = 1m; \alpha = 4$')
plt.plot(results_02[results_02['alpha']==6]['beta'], results_02[results_02['alpha']==6]['error'], '--', color = colors[2], label = r'$\Delta x = 1m; \alpha = 6$')
plt.plot(results_02[results_02['alpha']==8]['beta'], results_02[results_02['alpha']==8]['error'], '--', color = colors[3], label = r'$\Delta x = 1m; \alpha = 8$')
plt.plot(results_02[results_02['alpha']==10]['beta'], results_02[results_02['alpha']==10]['error'], '--', color = colors[4], label = r'$\Delta x = 1m; \alpha = 10$')

plt.plot(results_01[results_01['alpha']==2]['beta'], results_01[results_01['alpha']==2]['error'], '--', color = colors[0], label = r'$\Delta x = 2m; \alpha = 2$')
plt.plot(results_01[results_01['alpha']==4]['beta'], results_01[results_01['alpha']==4]['error'],'--', color = colors[1], label = r'$\Delta x = 2m; \alpha = 4$')
plt.plot(results_01[results_01['alpha']==6]['beta'], results_01[results_01['alpha']==6]['error'], '--', color = colors[2], label = r'$\Delta x = 2m; \alpha = 6$')
plt.plot(results_01[results_01['alpha']==8]['beta'], results_01[results_01['alpha']==8]['error'], '--', color = colors[3], label = r'$\Delta x = 2m; \alpha = 8$')
plt.plot(results_01[results_01['alpha']==10]['beta'], results_01[results_01['alpha']==10]['error'], '--', color = colors[4], label = r'$\Delta x = 2m; \alpha = 10$')

plt.xlabel(r"$\beta$")
plt.ylabel("L2 error norm")
plt.legend()
plt.show()

# %%
fixed_mesh = pd.read_excel('results.xlsx', sheet_name = 'fixed')

xlist = []
xlist.append(fixed_mesh.iloc[0][0.100])
xlist.append(fixed_mesh.iloc[0][0.200])
xlist.append(fixed_mesh.iloc[0][0.400])
xlist.append(fixed_mesh.iloc[0][0.500])
xlist.append(fixed_mesh.iloc[0][0.800])
xlist.append(fixed_mesh.iloc[0][1.000])
xlist.append(fixed_mesh.iloc[0][1.600])

errorlist = []
errorlist.append(fixed_mesh.iloc[2][0.100])
errorlist.append(fixed_mesh.iloc[2][0.200])
errorlist.append(fixed_mesh.iloc[2][0.400])
errorlist.append(fixed_mesh.iloc[2][0.500])
errorlist.append(fixed_mesh.iloc[2][0.800])
errorlist.append(fixed_mesh.iloc[2][1.000])
errorlist.append(fixed_mesh.iloc[2][1.600])

# %%
plt.plot(xlist, errorlist, '-o')
plt.ylabel('L2 error norm')
plt.xlabel(r'$\Delta x$ (m)')
plt.show()

# %%
import numpy as np
logx = np.log(xlist)
log_error = np.log(errorlist)
poly = np.polyfit(logx, log_error, 1)
print(poly[0])
xlist
# Out:
# 1.1256934621469226
# [2.0, 1.0, 0.5, 0.4, 0.25, 0.2, 0.125]

# %%
diff_time = pd.read_excel('/Users/mc4117/Documents/adapt_utils/unsteady/test_cases/trench_slant/results.xlsx', sheet_name = 'Sheet3')

error_list = []
time_list = []

for i in diff_time.columns.values[2:-2]:
    error_list.append(diff_time.iloc[0][0])
    time_list.append(diff_time.iloc[1][0])

fig, ax1 = plt.subplots()

color = 'tab:red'
ax1.set_xlabel('Number of timesteps per mesh movement')
ax1.set_ylabel('Mesh error', color=color)
#ax1.semilogx(diff_time.columns.values[2:-1], diff_time.iloc[0][2:-1], ':', label = r'$\alpha = 3$', color=color)
ax1.loglog(diff_time.columns.values[2:-2], diff_time.iloc[0].reset_index(drop = True)[2:-2], '-o', label = 'Mesh movement', color=color)
#ax1.semilogx(diff_time.columns.values[2:-1], diff_time.iloc[2][2:-1], ':', label = r'$\alpha = 5$', color=color)
ax1.loglog(diff_time.columns.values[2:-2], error_list, '--', label = 'Fixed mesh', color = color)
ax1.tick_params(axis='y', labelcolor=color)
plt.legend(loc = 9, bbox_to_anchor=(0.5, 0.73), title = "Error")
ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('Computational time (s)', color=color)  # we already handled the x-label with ax1
#ax2.semilogx(diff_time.columns.values[2:-1], diff_time.iloc[8][2:-1], ':', label = r'$\alpha = 3$', color=color)
ax2.loglog(diff_time.columns.values[2:-2], diff_time.iloc[1].reset_index(drop = True)[2:-2], '-o', label = 'Mesh movement', color=color)
#ax2.semilogx(diff_time.columns.values[2:-1], diff_time.iloc[10][2:-1], ':', label = r'$\alpha = 5$', color=color)
ax2.loglog(diff_time.columns.values[2:-2], time_list, '--', label = 'Fixed mesh',  color = color)
ax2.tick_params(axis='y', labelcolor=color)

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.legend(loc = 9, bbox_to_anchor=(0.5, 0.95), title = "Cost")
plt.show()

# %%
diff_time = pd.read_excel('/Users/mc4117/Documents/adapt_utils/unsteady/test_cases/trench_slant/results.xlsx', sheet_name = 'Sheet3')

error_list = []
time_list = []

for i in diff_time.columns.values[2:]:
    error_list.append(diff_time.iloc[4][0])
    time_list.append(diff_time.iloc[5][0])

fig, ax1 = plt.subplots()

color = 'tab:red'
ax1.set_xlabel('Number of timesteps per mesh movement')
ax1.set_ylabel('Mesh error', color=color)
#ax1.semilogx(diff_time.columns.values[2:-1], diff_time.iloc[0][2:-1], ':', label = r'$\alpha = 3$', color=color)
ax1.loglog(diff_time.iloc[3].reset_index(drop = True)[2:], diff_time.iloc[4].reset_index(drop = True)[2:], '-o', label = 'Mesh movement', color=color)
#ax1.semilogx(diff_time.columns.values[2:-1], diff_time.iloc[2][2:-1], ':', label = r'$\alpha = 5$', color=color)
ax1.loglog(diff_time.iloc[3].reset_index(drop = True)[2:], error_list, '--', label = 'Fixed mesh', color = color)
ax1.tick_params(axis='y', labelcolor=color)
plt.legend(loc = 9, bbox_to_anchor=(0.55, 0.78), title = "Error")
ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('Computational time (s)', color=color)  # we already handled the x-label with ax1
#ax2.semilogx(diff_time.columns.values[2:-1], diff_time.iloc[8][2:-1], ':', label = r'$\alpha = 3$', color=color)
ax2.loglog(diff_time.iloc[3].reset_index(drop = True)[2:], diff_time.iloc[5].reset_index(drop = True)[2:], '-o', label = 'Mesh movement', color=color)
#ax2.semilogx(diff_time.columns.values[2:-1], diff_time.iloc[10][2:-1], ':', label = r'$\alpha = 5$', color=color)
ax2.loglog(diff_time.iloc[3].reset_index(drop = True)[2:], time_list, '--', label = 'Fixed mesh',  color = color)
ax2.tick_params(axis='y', labelcolor=color)

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.legend(loc = 9, bbox_to_anchor=(0.55, 1), title = "Cost")
plt.show()
